# %%
from arcgis.gis import GIS
import platform
import psutil
import sys
import os
import shutil
import datetime
import time
from datetime import date, timedelta
import pandas as pd
import arcpy
from arcgis.features import GeoAccessor
import arcgis
from arcgis.raster import *
from arcgis.raster.analytics import *

arcgis.env.verbose=True

# %%
sys.path.append(r'C:\GitHub\code-base')
# from agol_credentials import kv_oceans_username, kv_oceans_password, kv_oceans_org
from agol_credentials import esri_oceans_username, esri_oceans_password, esri_oceans_org
gis = GIS(esri_oceans_org, esri_oceans_username, esri_oceans_password, verify_cert=True)
gis
# Out:
# GIS @ https://esri.maps.arcgis.com version:2025.3

# %%
print("**********Platform information**********")
print(f"System: {platform.system()}")
print(f"Node Name: {platform.node()}")
print(f"Release: {platform.release()}")
print(f"Version: {platform.version()}")
print(f"Machine: {platform.machine()}")
print(f"Processor: {platform.processor()}")
print("Memory information:")
mem = psutil.virtual_memory()
print(f"Total: {mem.total / (1024 ** 3):.2f} GB")
print(f"Available: {mem.available / (1024 ** 3):.2f} GB")
print(f"Used: {mem.used / (1024 ** 3):.2f} GB")
print(f"Percentage: {mem.percent}%")
print("CPU information:")
print(f"Physical cores: {psutil.cpu_count(logical=False)}")
print("**********Platform information**********")
# Out:
# **********Platform information**********
# System: Windows
# Node Name: KVanGraaf
# Release: 10
# Version: 10.0.22631
# Machine: AMD64
# Processor: Intel64 Family 6 Model 85 Stepping 7, GenuineIntel
# Memory information:
# Total: 127.69 GB
# Available: 89.26 GB
# Used: 38.43 GB
# Percentage: 30.1%
# CPU information:
# Physical cores: 18
# **********Platform information**********

# %%
# gfwapi_path = '/arcgis/home/gfwapiclient'
# if not os.path.isdir(gfwapi_path):
#     %pip install --target /arcgis/home/gfwapiclient gfw-api-python-client
#     # %pip install gfw-api-python-client
#     # %pip install --upgrade gfw-api-python-client

# %%
# sys.path.append(gfwapi_path)
import gfwapiclient as gfw
# Out:
# c:\Users\keit8223\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone_v2\Lib\site-packages\pyproj\__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
# sys.path.append('/arcgis/home/notebook/gfw')
from access_credentials import access_token_key

# %%
# workspace = "/arcgis/home/notebook/gfw"
workspace = r"D:\temp\gfw"
arcpy.env.workspace = workspace
arcpy.env.overwriteOutput = True

if not os.path.exists(workspace):
    os.makedirs(workspace)

# %%
access_token = os.environ.get(
    "GFW_API_ACCESS_TOKEN",
    access_token_key,
)

gfw_client = gfw.Client(
    access_token=access_token,
)

# %%
# Explore GFW Client Fourwings capabilities
print("=== GFW Client Fourwings Methods ===")
fourwings_methods = [method for method in dir(gfw_client.fourwings) if not method.startswith('_')]
for method in fourwings_methods:
    print(f"- {method}")

print("\n=== Create Report Method Details ===")
# Get help for create_report method
help(gfw_client.fourwings.create_report)

print("\n=== Fourwings Object Type ===")
print(type(gfw_client.fourwings))

# You can also check the docstring
print("\n=== Create Report Docstring ===")
print(gfw_client.fourwings.create_report.__doc__)

# Inspect the method signature
import inspect
print("\n=== Create Report Method Signature ===")
signature = inspect.signature(gfw_client.fourwings.create_report)
print(f"Parameters: {signature}")
for param_name, param in signature.parameters.items():
    print(f"  - {param_name}: {param.annotation if param.annotation != inspect.Parameter.empty else 'No type hint'}")
    if param.default != inspect.Parameter.empty:
        print(f"    Default: {param.default}")
# Out:
# === GFW Client Fourwings Methods ===
# - create_ais_presence_report
# - create_fishing_effort_report
# - create_report
# - create_sar_presence_report
#
# === Create Report Method Details ===
# Help on method create_report in module gfwapiclient.resources.fourwings.resources:
#
# async create_report(*, spatial_resolution: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportSpatialResolution, str, NoneType] = None, group_by: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportGroupBy, str, NoneType] = None, temporal_resolution: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportTemporalResolution, str, NoneType] = None, datasets: Union[List[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportDataset], List[str], NoneType] = None, filters: Optional[List[str]] = None, start_date: Union[datetime.date, str, NoneType] = None, end_date: Union[datetime.date, str, NoneType] = None, spatial_aggregation: Optional[bool] = None, geojson: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsGeometry, Dict[str, Any], NoneType] = None, region: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportRegion, Dict[str, Any], NoneType] = None, **kwargs: Dict[str, Any]) -> gfwapiclient.resources.fourwings.report.models.response.FourWingsReportResult method of gfwapiclient.resources.fourwings.resources.FourWingsResource instance
#     Create 4Wings report for a specified region.
#
#     Generates a report from the 4Wings API based on the provided parameters.
#
#     Generated report can serves following analytical needs:
#
#     - Fisheries compliance monitoring
#     - Fleet management
#     - Supply chain visibility
#     - Port traffic analysis
#     - Fleet management
#     - Supply chain visibility
#     - Dark vessel detection
#     - Remote area surveillance
#
#     For more details on the 4Wings data caveats, please refer to the official
#     Global Fishing Watch API documentation:
#
#     See: https://globalfishingwatch.org/our-apis/documentation#apparent-fishing-effort
#
#     See: https://globalfishingwatch.org/our-apis/documentation#sar-vessel-detections-data-caveats
#
#     See: https://globalfishingwatch.org/our-apis/documentation#ais-vessel-presence-caveats
#
#     **Disclaimer:**
#
#     AIS vessel presence is one of the largest datasets available. To prevent timeouts
#     and ensure optimal performance, keep requests manageable: prefer simple, small
#     regions and shorter time ranges (e.g., a few days).
#
#     Args:
#         spatial_resolution (Optional[Union[FourWingsReportSpatialResolution, str]], default="HIGH"):
#             Spatial resolution of the report. Defaults to `"HIGH"`.
#             Allowed values: `"HIGH"`, `"LOW"`.
#             Example: `"HIGH"`.
#
#         group_by (Optional[Union[FourWingsReportGroupBy, str]], default=None):
#             Grouping criteria for the report. Defaults to `None`.
#             Allowed values: `"VESSEL_ID"`, `"FLAG"`, `"GEARTYPE"`, `"FLAGANDGEARTYPE"`, `"MMSI"`.
#             Example: `"FLAG"`.
#
#         temporal_resolution (Optional[Union[FourWingsReportTemporalResolution, str]], default="HOURLY"):
#             Temporal resolution of the report. Defaults to `"HOURLY"`
#             Allowed values: `"HOURLY"`, `"DAILY"`, `"MONTHLY"`, `"YEARLY"`, `"ENTIRE"`.
#             Example: `"HOURLY"`.
#
#         datasets (Optional[Union[List[FourWingsReportDataset], List[str]]], default=["public-global-fishing-effort:latest"]):
#             Datasets that will be used to create the report. Defaults to `["public-global-fishing-effort:latest"]`.
#             Allowed values: `"public-global-fishing-effort:latest"`, `"public-global-sar-presence:latest"`,
#             `"public-global-presence:latest"`.
#             Example: `["public-global-fishing-effort:latest"]`.
#
#         filters (Optional[List[str]], default=None):
#             Filters to apply to the report. Defaults to `None`.
#             Example: `["flag in ('ESP', 'FRA')"]`.
#
#         start_date (Optional[Union[datetime.date, str]], default=None):
#             Start date for the report. Used to build `date_range`. Defaults to `None`.
#             Allowed values: A string in `ISO 8601 format` or `datetime.date` instance.
#             Example: `datetime.date(2021, 1, 1)` or `"2021-01-01"`.
#
#         end_date (Optional[Union[datetime.date, str]], default=None):
#             End date for the report. Used to build `date_range`. Defaults to `None`.
#             Allowed values: A string in `ISO 8601 format` or `datetime.date` instance.
#             Example: `datetime.date(2021, 1, 15)` or `"2021-01-15"`.
#
#         spatial_aggregation (Optional[bool], default=None):
#             Whether to spatially aggregate the report. Defaults to `None`.
#             Example: `True`.
#
#         geojson (Optional[Union[FourWingsGeometry, Dict[str, Any]]], default=None):
#             Custom GeoJSON geometry to filter the report. Defaults to `None`.
#             Example: `{"type": "Polygon", "coordinates": [...]}`.
#
#         region (Optional[Union[FourWingsReportRegion, Dict[str, Any]]], default=None):
#             Predefined region information to filter the report. Defaults to `None`.
#             Example: `{"dataset": "public-eez-areas", "id": "5690"}`.
#
#         **kwargs (Dict[str, Any]):
#             Additional keyword arguments.
#
#     Returns:
#         FourWingsReportResult:
#             The generated 4Wings report.
#
#     Raises:
#         GFWAPIClientError:
#             If the API request fails.
#
#         RequestParamsValidationError:
#             If the request parameters are invalid.
#
#         RequestBodyValidationError:
#             If the request body is invalid.
#
#
# === Fourwings Object Type ===
# <class 'gfwapiclient.resources.fourwings.resources.FourWingsResource'>
#
# === Create Report Docstring ===
# Create 4Wings report for a specified region.
#
#         Generates a report from the 4Wings API based on the provided parameters.
#
#         Generated report can serves following analytical needs:
#
#         - Fisheries compliance monitoring
#         - Fleet management
#         - Supply chain visibility
#         - Port traffic analysis
#         - Fleet management
#         - Supply chain visibility
#         - Dark vessel detection
#         - Remote area surveillance
#
#         For more details on the 4Wings data caveats, please refer to the official
#         Global Fishing Watch API documentation:
#
#         See: https://globalfishingwatch.org/our-apis/documentation#apparent-fishing-effort
#
#         See: https://globalfishingwatch.org/our-apis/documentation#sar-vessel-detections-data-caveats
#
#         See: https://globalfishingwatch.org/our-apis/documentation#ais-vessel-presence-caveats
#
#         **Disclaimer:**
#
#         AIS vessel presence is one of the largest datasets available. To prevent timeouts
#         and ensure optimal performance, keep requests manageable: prefer simple, small
#         regions and shorter time ranges (e.g., a few days).
#
#         Args:
#             spatial_resolution (Optional[Union[FourWingsReportSpatialResolution, str]], default="HIGH"):
#                 Spatial resolution of the report. Defaults to `"HIGH"`.
#                 Allowed values: `"HIGH"`, `"LOW"`.
#                 Example: `"HIGH"`.
#
#             group_by (Optional[Union[FourWingsReportGroupBy, str]], default=None):
#                 Grouping criteria for the report. Defaults to `None`.
#                 Allowed values: `"VESSEL_ID"`, `"FLAG"`, `"GEARTYPE"`, `"FLAGANDGEARTYPE"`, `"MMSI"`.
#                 Example: `"FLAG"`.
#
#             temporal_resolution (Optional[Union[FourWingsReportTemporalResolution, str]], default="HOURLY"):
#                 Temporal resolution of the report. Defaults to `"HOURLY"`
#                 Allowed values: `"HOURLY"`, `"DAILY"`, `"MONTHLY"`, `"YEARLY"`, `"ENTIRE"`.
#                 Example: `"HOURLY"`.
#
#             datasets (Optional[Union[List[FourWingsReportDataset], List[str]]], default=["public-global-fishing-effort:latest"]):
#                 Datasets that will be used to create the report. Defaults to `["public-global-fishing-effort:latest"]`.
#                 Allowed values: `"public-global-fishing-effort:latest"`, `"public-global-sar-presence:latest"`,
#                 `"public-global-presence:latest"`.
#                 Example: `["public-global-fishing-effort:latest"]`.
#
#             filters (Optional[List[str]], default=None):
#                 Filters to apply to the report. Defaults to `None`.
#                 Example: `["flag in ('ESP', 'FRA')"]`.
#
#             start_date (Optional[Union[datetime.date, str]], default=None):
#                 Start date for the report. Used to build `date_range`. Defaults to `None`.
#                 Allowed values: A string in `ISO 8601 format` or `datetime.date` instance.
#                 Example: `datetime.date(2021, 1, 1)` or `"2021-01-01"`.
#
#             end_date (Optional[Union[datetime.date, str]], default=None):
#                 End date for the report. Used to build `date_range`. Defaults to `None`.
#                 Allowed values: A string in `ISO 8601 format` or `datetime.date` instance.
#                 Example: `datetime.date(2021, 1, 15)` or `"2021-01-15"`.
#
#             spatial_aggregation (Optional[bool], default=None):
#                 Whether to spatially aggregate the report. Defaults to `None`.
#                 Example: `True`.
#
#             geojson (Optional[Union[FourWingsGeometry, Dict[str, Any]]], default=None):
#                 Custom GeoJSON geometry to filter the report. Defaults to `None`.
#                 Example: `{"type": "Polygon", "coordinates": [...]}`.
#
#             region (Optional[Union[FourWingsReportRegion, Dict[str, Any]]], default=None):
#                 Predefined region information to filter the report. Defaults to `None`.
#                 Example: `{"dataset": "public-eez-areas", "id": "5690"}`.
#
#             **kwargs (Dict[str, Any]):
#                 Additional keyword arguments.
#
#         Returns:
#             FourWingsReportResult:
#                 The generated 4Wings report.
#
#         Raises:
#             GFWAPIClientError:
#                 If the API request fails.
#
#             RequestParamsValidationError:
#                 If the request parameters are invalid.
#
#             RequestBodyValidationError:
#                 If the request body is invalid.
#
#
# === Create Report Method Signature ===
# Parameters: (*, spatial_resolution: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportSpatialResolution, str, NoneType] = None, group_by: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportGroupBy, str, NoneType] = None, temporal_resolution: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportTemporalResolution, str, NoneType] = None, datasets: Union[List[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportDataset], List[str], NoneType] = None, filters: Optional[List[str]] = None, start_date: Union[datetime.date, str, NoneType] = None, end_date: Union[datetime.date, str, NoneType] = None, spatial_aggregation: Optional[bool] = None, geojson: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsGeometry, Dict[str, Any], NoneType] = None, region: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportRegion, Dict[str, Any], NoneType] = None, **kwargs: Dict[str, Any]) -> gfwapiclient.resources.fourwings.report.models.response.FourWingsReportResult
#   - spatial_resolution: typing.Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportSpatialResolution, str, NoneType]
#     Default: None
#   - group_by: typing.Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportGroupBy, str, NoneType]
#     Default: None
#   - temporal_resolution: typing.Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportTemporalResolution, str, NoneType]
#     Default: None
#   - datasets: typing.Union[typing.List[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportDataset], typing.List[str], NoneType]
#     Default: None
#   - filters: typing.Optional[typing.List[str]]
#     Default: None
#   - start_date: typing.Union[datetime.date, str, NoneType]
#     Default: None
#   - end_date: typing.Union[datetime.date, str, NoneType]
#     Default: None
#   - spatial_aggregation: typing.Optional[bool]
#     Default: None
#   - geojson: typing.Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsGeometry, typing.Dict[str, typing.Any], NoneType]
#     Default: None
#   - region: typing.Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportRegion, typing.Dict[str, typing.Any], NoneType]
#     Default: None
#   - kwargs: typing.Dict[str, typing.Any]

# %%
global_geojson = {"type": "Polygon", "coordinates": [[[180, 90], [180, -90], [-180, -90], [-180, 90], [180, 90]]]}

# %% [markdown]
# ### ***** User Input *****

# %%
start = date(2020, 10, 22) ## YYYY, M, D
end = date.today()
product_name = "fishing_effort_hours_daily" ### keep it to four words (separated by underscores "_")
gfw_constant_raster = r"data/gfw_constant_raster.tif"
variable_name = "Fishing Effort - Matched"

# %%
date_list = []
d = start
while d <= end:
    date_list.append(d.strftime("%Y-%m-%d"))
    d += timedelta(days=1)

# %%
gdb_name = "gfw_" + product_name + ".gdb"
if not arcpy.Exists(gdb_name):
    arcpy.CreateFileGDB_management(workspace, gdb_name)

output_raster_workspace = os.path.join(workspace, product_name)
if not os.path.exists(output_raster_workspace):
    os.makedirs(output_raster_workspace)

# %%
for current_date in date_list:
    print(f"Processing date: {current_date}")
    date_name = current_date.replace("-", "")
    next_date = (pd.to_datetime(current_date) + pd.Timedelta(days=1)).strftime("%Y-%m-%d")
    print(f"Next date for processing: {next_date}")
    feature_class = os.path.join(workspace, gdb_name, product_name + "_" + str(date_name))
    if arcpy.Exists(feature_class):
        print(f"Feature class {feature_class} already exists. Skipping.")
        continue
    try:
        print("Waiting 5 seconds to eliminate too many requests error...")
        time.sleep(5)
        dt_start = datetime.now()
        var_name_lower = variable_name.lower()
        if "unmatched" in var_name_lower:
            matched_param = 'false'
        elif "matched" in var_name_lower:
            matched_param = 'true'
        else:
            matched_param = 'true'  # default

        gfw_report = await gfw_client.fourwings.create_report(
            datasets=["public-global-fishing-effort:latest"],
            spatial_resolution="HIGH",
            temporal_resolution="DAILY",
            group_by="GEARTYPE",
            matched=matched_param,
            start_date=current_date,
            end_date=next_date,
            geojson=global_geojson,
        )
        dt_api = datetime.now()
        print(f"Elapsed time: {dt_api - dt_start} to query GFW API for Report.")
        gfw_report_df = gfw_report.df()
        gfw_report_df['lat'] = gfw_report_df['lat'] + 0.005
        gfw_report_df['lon'] = gfw_report_df['lon'] + 0.005
        dt_dataframe = datetime.now()
        print(f"Elapsed time: {dt_dataframe - dt_api} to create dataframe.")
        gfw_sedf = pd.DataFrame.spatial.from_xy(df = gfw_report_df, x_column = "lon", y_column = "lat", sr=4326)
        dt_sdef = datetime.now()
        print(f"Elapsed time: {dt_sdef - dt_api} to create spatially enabled dataframe.")
        gfw_sedf.spatial.to_featureclass(feature_class)
        dt_fc = datetime.now()
        print(f"Elapsed time: {dt_fc - dt_sdef} to create feature class.")
        print(f"Completed processing date {current_date} API to Feature Class.")

        output_raster = os.path.join(output_raster_workspace, product_name + '_' + str(date_name) + ".tif")
        
        arcpy.conversion.PointToRaster(
            in_features=feature_class,
            value_field="hours",
            out_rasterdataset=output_raster,
            cell_assignment="SUM",
            priority_field="NONE",
            cellsize=0.01,  # adjust cell size as needed 0.1 for LOW and 0.01 for HIGH
            build_rat="BUILD"
        )

        dt_ras = datetime.now()
        print(f"Elapsed time: {dt_ras - dt_fc} to create raster from points.")
        print(f"Completed processing date {current_date} Point to Raster.")

        
        final_raster = os.path.join(output_raster_workspace, product_name + '_' + str(date_name) + "_global.tif")
        with arcpy.EnvManager(outputCoordinateSystem='GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]]',
                              snapRaster=gfw_constant_raster, cellSize=gfw_constant_raster, extent=gfw_constant_raster):
            global_raster = arcpy.sa.Plus(
                in_raster_or_constant1=output_raster,
                in_raster_or_constant2=gfw_constant_raster
            )
            global_raster.save(final_raster)
        
        arcpy.management.Delete(output_raster)
        print(f"Deleted intermediate raster: {output_raster}")

        print(f"***** Completed processing date {current_date} *****")
    except Exception as e:
        print(f"Error processing date {current_date}: {e}")
# Out:
# Processing date: 2020-10-22
# Next date for processing: 2020-10-23
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.447564 to query GFW API for Report.
# Elapsed time: 0:00:00.745650 to create dataframe.
# Elapsed time: 0:00:20.727571 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.424155 to create feature class.
# Completed processing date 2020-10-22 API to Feature Class.
# Elapsed time: 0:00:20.929964 to create raster from points.
# Completed processing date 2020-10-22 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201022.tif
# ***** Completed processing date 2020-10-22 *****
# Processing date: 2020-10-23
# Next date for processing: 2020-10-24
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.667477 to query GFW API for Report.
# Elapsed time: 0:00:00.734831 to create dataframe.
# Elapsed time: 0:00:19.523665 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.928907 to create feature class.
# Completed processing date 2020-10-23 API to Feature Class.
# Elapsed time: 0:00:20.230893 to create raster from points.
# Completed processing date 2020-10-23 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201023.tif
# ***** Completed processing date 2020-10-23 *****
# Processing date: 2020-10-24
# Next date for processing: 2020-10-25
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.084985 to query GFW API for Report.
# Elapsed time: 0:00:00.824194 to create dataframe.
# Elapsed time: 0:00:21.595263 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.866837 to create feature class.
# Completed processing date 2020-10-24 API to Feature Class.
# Elapsed time: 0:00:20.221503 to create raster from points.
# Completed processing date 2020-10-24 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201024.tif
# ***** Completed processing date 2020-10-24 *****
# Processing date: 2020-10-25
# Next date for processing: 2020-10-26
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.000052 to query GFW API for Report.
# Elapsed time: 0:00:00.937530 to create dataframe.
# Elapsed time: 0:00:24.164233 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.162483 to create feature class.
# Completed processing date 2020-10-25 API to Feature Class.
# Elapsed time: 0:00:20.448817 to create raster from points.
# Completed processing date 2020-10-25 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201025.tif
# ***** Completed processing date 2020-10-25 *****
# Processing date: 2020-10-26
# Next date for processing: 2020-10-27
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.319781 to query GFW API for Report.
# Elapsed time: 0:00:01.082013 to create dataframe.
# Elapsed time: 0:00:27.779702 to create spatially enabled dataframe.
# Elapsed time: 0:00:12.122985 to create feature class.
# Completed processing date 2020-10-26 API to Feature Class.
# Elapsed time: 0:00:20.394321 to create raster from points.
# Completed processing date 2020-10-26 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201026.tif
# ***** Completed processing date 2020-10-26 *****
# Processing date: 2020-10-27
# Next date for processing: 2020-10-28
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.198200 to query GFW API for Report.
# Elapsed time: 0:00:00.983543 to create dataframe.
# Elapsed time: 0:00:25.364027 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.704840 to create feature class.
# Completed processing date 2020-10-27 API to Feature Class.
# Elapsed time: 0:00:20.318366 to create raster from points.
# Completed processing date 2020-10-27 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201027.tif
# ***** Completed processing date 2020-10-27 *****
# Processing date: 2020-10-28
# Next date for processing: 2020-10-29
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.381716 to query GFW API for Report.
# Elapsed time: 0:00:00.961770 to create dataframe.
# Elapsed time: 0:00:24.379499 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.937413 to create feature class.
# Completed processing date 2020-10-28 API to Feature Class.
# Elapsed time: 0:00:20.031501 to create raster from points.
# Completed processing date 2020-10-28 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201028.tif
# ***** Completed processing date 2020-10-28 *****
# Processing date: 2020-10-29
# Next date for processing: 2020-10-30
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.983503 to query GFW API for Report.
# Elapsed time: 0:00:00.950462 to create dataframe.
# Elapsed time: 0:00:24.152593 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.197161 to create feature class.
# Completed processing date 2020-10-29 API to Feature Class.
# Elapsed time: 0:00:19.903206 to create raster from points.
# Completed processing date 2020-10-29 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201029.tif
# ***** Completed processing date 2020-10-29 *****
# Processing date: 2020-10-30
# Next date for processing: 2020-10-31
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.164508 to query GFW API for Report.
# Elapsed time: 0:00:00.930781 to create dataframe.
# Elapsed time: 0:00:23.466671 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.649874 to create feature class.
# Completed processing date 2020-10-30 API to Feature Class.
# Elapsed time: 0:00:19.868340 to create raster from points.
# Completed processing date 2020-10-30 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201030.tif
# ***** Completed processing date 2020-10-30 *****
# Processing date: 2020-10-31
# Next date for processing: 2020-11-01
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.792120 to query GFW API for Report.
# Elapsed time: 0:00:00.862290 to create dataframe.
# Elapsed time: 0:00:22.260583 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.244254 to create feature class.
# Completed processing date 2020-10-31 API to Feature Class.
# Elapsed time: 0:00:20.349998 to create raster from points.
# Completed processing date 2020-10-31 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201031.tif
# ***** Completed processing date 2020-10-31 *****
# Processing date: 2020-11-01
# Next date for processing: 2020-11-02
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.277034 to query GFW API for Report.
# Elapsed time: 0:00:00.899982 to create dataframe.
# Elapsed time: 0:00:23.451190 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.731721 to create feature class.
# Completed processing date 2020-11-01 API to Feature Class.
# Elapsed time: 0:00:19.821942 to create raster from points.
# Completed processing date 2020-11-01 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201101.tif
# ***** Completed processing date 2020-11-01 *****
# Processing date: 2020-11-02
# Next date for processing: 2020-11-03
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.894373 to query GFW API for Report.
# Elapsed time: 0:00:00.784257 to create dataframe.
# Elapsed time: 0:00:20.358736 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.178528 to create feature class.
# Completed processing date 2020-11-02 API to Feature Class.
# Elapsed time: 0:00:19.744129 to create raster from points.
# Completed processing date 2020-11-02 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201102.tif
# ***** Completed processing date 2020-11-02 *****
# Processing date: 2020-11-03
# Next date for processing: 2020-11-04
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.081431 to query GFW API for Report.
# Elapsed time: 0:00:00.737440 to create dataframe.
# Elapsed time: 0:00:19.616879 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.267123 to create feature class.
# Completed processing date 2020-11-03 API to Feature Class.
# Elapsed time: 0:00:19.941505 to create raster from points.
# Completed processing date 2020-11-03 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201103.tif
# ***** Completed processing date 2020-11-03 *****
# Processing date: 2020-11-04
# Next date for processing: 2020-11-05
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.707710 to query GFW API for Report.
# Elapsed time: 0:00:00.875021 to create dataframe.
# Elapsed time: 0:00:23.455465 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.291397 to create feature class.
# Completed processing date 2020-11-04 API to Feature Class.
# Elapsed time: 0:00:19.248968 to create raster from points.
# Completed processing date 2020-11-04 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201104.tif
# ***** Completed processing date 2020-11-04 *****
# Processing date: 2020-11-05
# Next date for processing: 2020-11-06
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.559406 to query GFW API for Report.
# Elapsed time: 0:00:00.902967 to create dataframe.
# Elapsed time: 0:00:23.335667 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.531222 to create feature class.
# Completed processing date 2020-11-05 API to Feature Class.
# Elapsed time: 0:00:20.740383 to create raster from points.
# Completed processing date 2020-11-05 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201105.tif
# ***** Completed processing date 2020-11-05 *****
# Processing date: 2020-11-06
# Next date for processing: 2020-11-07
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.079274 to query GFW API for Report.
# Elapsed time: 0:00:00.908154 to create dataframe.
# Elapsed time: 0:00:23.937020 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.854790 to create feature class.
# Completed processing date 2020-11-06 API to Feature Class.
# Elapsed time: 0:00:20.921224 to create raster from points.
# Completed processing date 2020-11-06 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201106.tif
# ***** Completed processing date 2020-11-06 *****
# Processing date: 2020-11-07
# Next date for processing: 2020-11-08
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.289836 to query GFW API for Report.
# Elapsed time: 0:00:00.735456 to create dataframe.
# Elapsed time: 0:00:18.960758 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.820379 to create feature class.
# Completed processing date 2020-11-07 API to Feature Class.
# Elapsed time: 0:00:20.147820 to create raster from points.
# Completed processing date 2020-11-07 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201107.tif
# ***** Completed processing date 2020-11-07 *****
# Processing date: 2020-11-08
# Next date for processing: 2020-11-09
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.372333 to query GFW API for Report.
# Elapsed time: 0:00:00.683690 to create dataframe.
# Elapsed time: 0:00:18.651366 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.001001 to create feature class.
# Completed processing date 2020-11-08 API to Feature Class.
# Elapsed time: 0:00:20.579490 to create raster from points.
# Completed processing date 2020-11-08 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201108.tif
# ***** Completed processing date 2020-11-08 *****
# Processing date: 2020-11-09
# Next date for processing: 2020-11-10
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.416456 to query GFW API for Report.
# Elapsed time: 0:00:01.013452 to create dataframe.
# Elapsed time: 0:00:25.369502 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.077231 to create feature class.
# Completed processing date 2020-11-09 API to Feature Class.
# Elapsed time: 0:00:21.301611 to create raster from points.
# Completed processing date 2020-11-09 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201109.tif
# ***** Completed processing date 2020-11-09 *****
# Processing date: 2020-11-10
# Next date for processing: 2020-11-11
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.477322 to query GFW API for Report.
# Elapsed time: 0:00:01.058266 to create dataframe.
# Elapsed time: 0:00:27.070140 to create spatially enabled dataframe.
# Elapsed time: 0:00:12.173892 to create feature class.
# Completed processing date 2020-11-10 API to Feature Class.
# Elapsed time: 0:00:21.338672 to create raster from points.
# Completed processing date 2020-11-10 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201110.tif
# ***** Completed processing date 2020-11-10 *****
# Processing date: 2020-11-11
# Next date for processing: 2020-11-12
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.440920 to query GFW API for Report.
# Elapsed time: 0:00:00.995347 to create dataframe.
# Elapsed time: 0:00:26.595851 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.889636 to create feature class.
# Completed processing date 2020-11-11 API to Feature Class.
# Elapsed time: 0:00:20.127233 to create raster from points.
# Completed processing date 2020-11-11 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201111.tif
# ***** Completed processing date 2020-11-11 *****
# Processing date: 2020-11-12
# Next date for processing: 2020-11-13
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.139483 to query GFW API for Report.
# Elapsed time: 0:00:00.928253 to create dataframe.
# Elapsed time: 0:00:24.561046 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.602083 to create feature class.
# Completed processing date 2020-11-12 API to Feature Class.
# Elapsed time: 0:00:21.626396 to create raster from points.
# Completed processing date 2020-11-12 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201112.tif
# ***** Completed processing date 2020-11-12 *****
# Processing date: 2020-11-13
# Next date for processing: 2020-11-14
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.923298 to query GFW API for Report.
# Elapsed time: 0:00:00.828186 to create dataframe.
# Elapsed time: 0:00:23.180358 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.213421 to create feature class.
# Completed processing date 2020-11-13 API to Feature Class.
# Elapsed time: 0:00:22.212228 to create raster from points.
# Completed processing date 2020-11-13 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201113.tif
# ***** Completed processing date 2020-11-13 *****
# Processing date: 2020-11-14
# Next date for processing: 2020-11-15
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.981422 to query GFW API for Report.
# Elapsed time: 0:00:00.807336 to create dataframe.
# Elapsed time: 0:00:21.360137 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.918251 to create feature class.
# Completed processing date 2020-11-14 API to Feature Class.
# Elapsed time: 0:00:20.591057 to create raster from points.
# Completed processing date 2020-11-14 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201114.tif
# ***** Completed processing date 2020-11-14 *****
# Processing date: 2020-11-15
# Next date for processing: 2020-11-16
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.623586 to query GFW API for Report.
# Elapsed time: 0:00:00.822234 to create dataframe.
# Elapsed time: 0:00:22.790966 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.055414 to create feature class.
# Completed processing date 2020-11-15 API to Feature Class.
# Elapsed time: 0:00:20.075862 to create raster from points.
# Completed processing date 2020-11-15 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201115.tif
# ***** Completed processing date 2020-11-15 *****
# Processing date: 2020-11-16
# Next date for processing: 2020-11-17
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.187361 to query GFW API for Report.
# Elapsed time: 0:00:01.006736 to create dataframe.
# Elapsed time: 0:00:27.460730 to create spatially enabled dataframe.
# Elapsed time: 0:00:12.140310 to create feature class.
# Completed processing date 2020-11-16 API to Feature Class.
# Elapsed time: 0:00:22.125170 to create raster from points.
# Completed processing date 2020-11-16 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201116.tif
# ***** Completed processing date 2020-11-16 *****
# Processing date: 2020-11-17
# Next date for processing: 2020-11-18
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.094317 to query GFW API for Report.
# Elapsed time: 0:00:00.977799 to create dataframe.
# Elapsed time: 0:00:24.135287 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.135737 to create feature class.
# Completed processing date 2020-11-17 API to Feature Class.
# Elapsed time: 0:00:21.616124 to create raster from points.
# Completed processing date 2020-11-17 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201117.tif
# ***** Completed processing date 2020-11-17 *****
# Processing date: 2020-11-18
# Next date for processing: 2020-11-19
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.757997 to query GFW API for Report.
# Elapsed time: 0:00:00.909106 to create dataframe.
# Elapsed time: 0:00:22.780223 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.528558 to create feature class.
# Completed processing date 2020-11-18 API to Feature Class.
# Elapsed time: 0:00:21.718321 to create raster from points.
# Completed processing date 2020-11-18 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201118.tif
# ***** Completed processing date 2020-11-18 *****
# Processing date: 2020-11-19
# Next date for processing: 2020-11-20
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.344870 to query GFW API for Report.
# Elapsed time: 0:00:00.860637 to create dataframe.
# Elapsed time: 0:00:22.102595 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.392646 to create feature class.
# Completed processing date 2020-11-19 API to Feature Class.
# Elapsed time: 0:00:21.451517 to create raster from points.
# Completed processing date 2020-11-19 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201119.tif
# ***** Completed processing date 2020-11-19 *****
# Processing date: 2020-11-20
# Next date for processing: 2020-11-21
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.724185 to query GFW API for Report.
# Elapsed time: 0:00:00.807188 to create dataframe.
# Elapsed time: 0:00:20.659850 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.703098 to create feature class.
# Completed processing date 2020-11-20 API to Feature Class.
# Elapsed time: 0:00:21.410283 to create raster from points.
# Completed processing date 2020-11-20 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201120.tif
# ***** Completed processing date 2020-11-20 *****
# Processing date: 2020-11-21
# Next date for processing: 2020-11-22
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.948582 to query GFW API for Report.
# Elapsed time: 0:00:00.788911 to create dataframe.
# Elapsed time: 0:00:20.188607 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.546686 to create feature class.
# Completed processing date 2020-11-21 API to Feature Class.
# Elapsed time: 0:00:21.637211 to create raster from points.
# Completed processing date 2020-11-21 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201121.tif
# ***** Completed processing date 2020-11-21 *****
# Processing date: 2020-11-22
# Next date for processing: 2020-11-23
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.841171 to query GFW API for Report.
# Elapsed time: 0:00:00.747764 to create dataframe.
# Elapsed time: 0:00:19.512441 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.178675 to create feature class.
# Completed processing date 2020-11-22 API to Feature Class.
# Elapsed time: 0:00:21.280236 to create raster from points.
# Completed processing date 2020-11-22 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201122.tif
# ***** Completed processing date 2020-11-22 *****
# Processing date: 2020-11-23
# Next date for processing: 2020-11-24
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.234719 to query GFW API for Report.
# Elapsed time: 0:00:00.922913 to create dataframe.
# Elapsed time: 0:00:23.073449 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.710089 to create feature class.
# Completed processing date 2020-11-23 API to Feature Class.
# Elapsed time: 0:00:21.150726 to create raster from points.
# Completed processing date 2020-11-23 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201123.tif
# ***** Completed processing date 2020-11-23 *****
# Processing date: 2020-11-24
# Next date for processing: 2020-11-25
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.442337 to query GFW API for Report.
# Elapsed time: 0:00:01.015368 to create dataframe.
# Elapsed time: 0:00:25.762003 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.599812 to create feature class.
# Completed processing date 2020-11-24 API to Feature Class.
# Elapsed time: 0:00:21.660335 to create raster from points.
# Completed processing date 2020-11-24 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201124.tif
# ***** Completed processing date 2020-11-24 *****
# Processing date: 2020-11-25
# Next date for processing: 2020-11-26
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.467596 to query GFW API for Report.
# Elapsed time: 0:00:01.084485 to create dataframe.
# Elapsed time: 0:00:25.953165 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.898594 to create feature class.
# Completed processing date 2020-11-25 API to Feature Class.
# Elapsed time: 0:00:22.237543 to create raster from points.
# Completed processing date 2020-11-25 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201125.tif
# ***** Completed processing date 2020-11-25 *****
# Processing date: 2020-11-26
# Next date for processing: 2020-11-27
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.401669 to query GFW API for Report.
# Elapsed time: 0:00:00.999546 to create dataframe.
# Elapsed time: 0:00:25.510483 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.380916 to create feature class.
# Completed processing date 2020-11-26 API to Feature Class.
# Elapsed time: 0:00:21.751256 to create raster from points.
# Completed processing date 2020-11-26 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201126.tif
# ***** Completed processing date 2020-11-26 *****
# Processing date: 2020-11-27
# Next date for processing: 2020-11-28
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.413362 to query GFW API for Report.
# Elapsed time: 0:00:00.677086 to create dataframe.
# Elapsed time: 0:00:18.216616 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.912255 to create feature class.
# Completed processing date 2020-11-27 API to Feature Class.
# Elapsed time: 0:00:21.655042 to create raster from points.
# Completed processing date 2020-11-27 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201127.tif
# ***** Completed processing date 2020-11-27 *****
# Processing date: 2020-11-28
# Next date for processing: 2020-11-29
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.971968 to query GFW API for Report.
# Elapsed time: 0:00:00.708887 to create dataframe.
# Elapsed time: 0:00:18.387057 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.810272 to create feature class.
# Completed processing date 2020-11-28 API to Feature Class.
# Elapsed time: 0:00:21.670362 to create raster from points.
# Completed processing date 2020-11-28 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201128.tif
# ***** Completed processing date 2020-11-28 *****
# Processing date: 2020-11-29
# Next date for processing: 2020-11-30
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.118021 to query GFW API for Report.
# Elapsed time: 0:00:00.791860 to create dataframe.
# Elapsed time: 0:00:20.157838 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.450945 to create feature class.
# Completed processing date 2020-11-29 API to Feature Class.
# Elapsed time: 0:00:21.752611 to create raster from points.
# Completed processing date 2020-11-29 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201129.tif
# ***** Completed processing date 2020-11-29 *****
# Processing date: 2020-11-30
# Next date for processing: 2020-12-01
# Waiting 5 seconds to eliminate too many requests error...
# Error processing date 2020-11-30: Error code: 404 - {'Op': 'Get', 'URL': 'https://gateway.api.globalfishingwatch.org/v3/datasets?limit=10000&offset=0&ids=public-global-fishing-effort:latest&cache=false', 'Err': {'Op': 'read', 'Net': 'tcp', 'Source': {'IP': 'fddf:3978:feb1:d745::c001', 'Port': 18617, 'Zone': ''}, 'Addr': {'IP': '2606:4700:10::6814:23d8', 'Port': 443, 'Zone': ''}, 'Err': {'Syscall': 'read', 'Err': 104}}}
# Body: {'Op': 'Get', 'URL': 'https://gateway.api.globalfishingwatch.org/v3/datasets?limit=10000&offset=0&ids=public-global-fishing-effort:latest&cache=false', 'Err': {'Op': 'read', 'Net': 'tcp', 'Source': {'IP': 'fddf:3978:feb1:d745::c001', 'Port': 18617, 'Zone': ''}, 'Addr': {'IP': '2606:4700:10::6814:23d8', 'Port': 443, 'Zone': ''}, 'Err': {'Syscall': 'read', 'Err': 104}}}
# Processing date: 2020-12-01
# Next date for processing: 2020-12-02
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.542335 to query GFW API for Report.
# Elapsed time: 0:00:00.949894 to create dataframe.
# Elapsed time: 0:00:23.544222 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.980856 to create feature class.
# Completed processing date 2020-12-01 API to Feature Class.
# Elapsed time: 0:00:21.633728 to create raster from points.
# Completed processing date 2020-12-01 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201201.tif
# ***** Completed processing date 2020-12-01 *****
# Processing date: 2020-12-02
# Next date for processing: 2020-12-03
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.626897 to query GFW API for Report.
# Elapsed time: 0:00:00.822706 to create dataframe.
# Elapsed time: 0:00:21.345653 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.070307 to create feature class.
# Completed processing date 2020-12-02 API to Feature Class.
# Elapsed time: 0:00:21.409915 to create raster from points.
# Completed processing date 2020-12-02 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201202.tif
# ***** Completed processing date 2020-12-02 *****
# Processing date: 2020-12-03
# Next date for processing: 2020-12-04
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.906799 to query GFW API for Report.
# Elapsed time: 0:00:00.730045 to create dataframe.
# Elapsed time: 0:00:19.127530 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.077525 to create feature class.
# Completed processing date 2020-12-03 API to Feature Class.
# Elapsed time: 0:00:21.954172 to create raster from points.
# Completed processing date 2020-12-03 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201203.tif
# ***** Completed processing date 2020-12-03 *****
# Processing date: 2020-12-04
# Next date for processing: 2020-12-05
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.831691 to query GFW API for Report.
# Elapsed time: 0:00:00.705888 to create dataframe.
# Elapsed time: 0:00:18.086400 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.697959 to create feature class.
# Completed processing date 2020-12-04 API to Feature Class.
# Elapsed time: 0:00:21.416479 to create raster from points.
# Completed processing date 2020-12-04 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201204.tif
# ***** Completed processing date 2020-12-04 *****
# Processing date: 2020-12-05
# Next date for processing: 2020-12-06
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.067673 to query GFW API for Report.
# Elapsed time: 0:00:00.744131 to create dataframe.
# Elapsed time: 0:00:19.690784 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.365754 to create feature class.
# Completed processing date 2020-12-05 API to Feature Class.
# Elapsed time: 0:00:21.884649 to create raster from points.
# Completed processing date 2020-12-05 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201205.tif
# ***** Completed processing date 2020-12-05 *****
# Processing date: 2020-12-06
# Next date for processing: 2020-12-07
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.876799 to query GFW API for Report.
# Elapsed time: 0:00:00.840104 to create dataframe.
# Elapsed time: 0:00:21.173888 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.041427 to create feature class.
# Completed processing date 2020-12-06 API to Feature Class.
# Elapsed time: 0:00:22.238570 to create raster from points.
# Completed processing date 2020-12-06 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201206.tif
# ***** Completed processing date 2020-12-06 *****
# Processing date: 2020-12-07
# Next date for processing: 2020-12-08
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.653011 to query GFW API for Report.
# Elapsed time: 0:00:00.865925 to create dataframe.
# Elapsed time: 0:00:21.601135 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.056365 to create feature class.
# Completed processing date 2020-12-07 API to Feature Class.
# Elapsed time: 0:00:22.013418 to create raster from points.
# Completed processing date 2020-12-07 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201207.tif
# ***** Completed processing date 2020-12-07 *****
# Processing date: 2020-12-08
# Next date for processing: 2020-12-09
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.703116 to query GFW API for Report.
# Elapsed time: 0:00:00.804184 to create dataframe.
# Elapsed time: 0:00:20.982742 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.919675 to create feature class.
# Completed processing date 2020-12-08 API to Feature Class.
# Elapsed time: 0:00:22.177547 to create raster from points.
# Completed processing date 2020-12-08 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201208.tif
# ***** Completed processing date 2020-12-08 *****
# Processing date: 2020-12-09
# Next date for processing: 2020-12-10
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:07.327418 to query GFW API for Report.
# Elapsed time: 0:00:01.093746 to create dataframe.
# Elapsed time: 0:00:26.221888 to create spatially enabled dataframe.
# Elapsed time: 0:00:12.022641 to create feature class.
# Completed processing date 2020-12-09 API to Feature Class.
# Elapsed time: 0:00:22.204308 to create raster from points.
# Completed processing date 2020-12-09 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201209.tif
# ***** Completed processing date 2020-12-09 *****
# Processing date: 2020-12-10
# Next date for processing: 2020-12-11
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:09.378122 to query GFW API for Report.
# Elapsed time: 0:00:01.072411 to create dataframe.
# Elapsed time: 0:00:26.508418 to create spatially enabled dataframe.
# Elapsed time: 0:00:12.136489 to create feature class.
# Completed processing date 2020-12-10 API to Feature Class.
# Elapsed time: 0:00:22.503369 to create raster from points.
# Completed processing date 2020-12-10 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201210.tif
# ***** Completed processing date 2020-12-10 *****
# Processing date: 2020-12-11
# Next date for processing: 2020-12-12
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.770643 to query GFW API for Report.
# Elapsed time: 0:00:01.021032 to create dataframe.
# Elapsed time: 0:00:24.664521 to create spatially enabled dataframe.
# Elapsed time: 0:00:11.344761 to create feature class.
# Completed processing date 2020-12-11 API to Feature Class.
# Elapsed time: 0:00:22.678330 to create raster from points.
# Completed processing date 2020-12-11 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201211.tif
# ***** Completed processing date 2020-12-11 *****
# Processing date: 2020-12-12
# Next date for processing: 2020-12-13
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.259182 to query GFW API for Report.
# Elapsed time: 0:00:00.850572 to create dataframe.
# Elapsed time: 0:00:21.278552 to create spatially enabled dataframe.
# Elapsed time: 0:00:10.098762 to create feature class.
# Completed processing date 2020-12-12 API to Feature Class.
# Elapsed time: 0:00:22.080701 to create raster from points.
# Completed processing date 2020-12-12 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201212.tif
# ***** Completed processing date 2020-12-12 *****
# Processing date: 2020-12-13
# Next date for processing: 2020-12-14
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.397566 to query GFW API for Report.
# Elapsed time: 0:00:00.701829 to create dataframe.
# Elapsed time: 0:00:17.925562 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.545408 to create feature class.
# Completed processing date 2020-12-13 API to Feature Class.
# Elapsed time: 0:00:21.921235 to create raster from points.
# Completed processing date 2020-12-13 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201213.tif
# ***** Completed processing date 2020-12-13 *****
# Processing date: 2020-12-14
# Next date for processing: 2020-12-15
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.937735 to query GFW API for Report.
# Elapsed time: 0:00:00.623951 to create dataframe.
# Elapsed time: 0:00:17.140635 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.285329 to create feature class.
# Completed processing date 2020-12-14 API to Feature Class.
# Elapsed time: 0:00:22.109695 to create raster from points.
# Completed processing date 2020-12-14 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201214.tif
# ***** Completed processing date 2020-12-14 *****
# Processing date: 2020-12-15
# Next date for processing: 2020-12-16
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.764337 to query GFW API for Report.
# Elapsed time: 0:00:00.729953 to create dataframe.
# Elapsed time: 0:00:19.179289 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.179804 to create feature class.
# Completed processing date 2020-12-15 API to Feature Class.
# Elapsed time: 0:00:22.298039 to create raster from points.
# Completed processing date 2020-12-15 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201215.tif
# ***** Completed processing date 2020-12-15 *****
# Processing date: 2020-12-16
# Next date for processing: 2020-12-17
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.618253 to query GFW API for Report.
# Elapsed time: 0:00:00.747390 to create dataframe.
# Elapsed time: 0:00:19.626967 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.222799 to create feature class.
# Completed processing date 2020-12-16 API to Feature Class.
# Elapsed time: 0:00:22.327795 to create raster from points.
# Completed processing date 2020-12-16 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201216.tif
# ***** Completed processing date 2020-12-16 *****
# Processing date: 2020-12-17
# Next date for processing: 2020-12-18
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:08.380364 to query GFW API for Report.
# Elapsed time: 0:00:00.771140 to create dataframe.
# Elapsed time: 0:00:19.909827 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.621725 to create feature class.
# Completed processing date 2020-12-17 API to Feature Class.
# Elapsed time: 0:00:21.738049 to create raster from points.
# Completed processing date 2020-12-17 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201217.tif
# ***** Completed processing date 2020-12-17 *****
# Processing date: 2020-12-18
# Next date for processing: 2020-12-19
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.275934 to query GFW API for Report.
# Elapsed time: 0:00:00.716052 to create dataframe.
# Elapsed time: 0:00:17.787304 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.929062 to create feature class.
# Completed processing date 2020-12-18 API to Feature Class.
# Elapsed time: 0:00:22.545291 to create raster from points.
# Completed processing date 2020-12-18 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201218.tif
# ***** Completed processing date 2020-12-18 *****
# Processing date: 2020-12-19
# Next date for processing: 2020-12-20
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.182563 to query GFW API for Report.
# Elapsed time: 0:00:00.596015 to create dataframe.
# Elapsed time: 0:00:15.348814 to create spatially enabled dataframe.
# Elapsed time: 0:00:07.954089 to create feature class.
# Completed processing date 2020-12-19 API to Feature Class.
# Elapsed time: 0:00:22.376286 to create raster from points.
# Completed processing date 2020-12-19 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201219.tif
# ***** Completed processing date 2020-12-19 *****
# Processing date: 2020-12-20
# Next date for processing: 2020-12-21
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.899073 to query GFW API for Report.
# Elapsed time: 0:00:00.634583 to create dataframe.
# Elapsed time: 0:00:17.139144 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.619567 to create feature class.
# Completed processing date 2020-12-20 API to Feature Class.
# Elapsed time: 0:00:22.270475 to create raster from points.
# Completed processing date 2020-12-20 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201220.tif
# ***** Completed processing date 2020-12-20 *****
# Processing date: 2020-12-21
# Next date for processing: 2020-12-22
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.665845 to query GFW API for Report.
# Elapsed time: 0:00:00.701560 to create dataframe.
# Elapsed time: 0:00:18.912050 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.988973 to create feature class.
# Completed processing date 2020-12-21 API to Feature Class.
# Elapsed time: 0:00:22.011597 to create raster from points.
# Completed processing date 2020-12-21 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201221.tif
# ***** Completed processing date 2020-12-21 *****
# Processing date: 2020-12-22
# Next date for processing: 2020-12-23
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.235008 to query GFW API for Report.
# Elapsed time: 0:00:00.755022 to create dataframe.
# Elapsed time: 0:00:19.618807 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.343189 to create feature class.
# Completed processing date 2020-12-22 API to Feature Class.
# Elapsed time: 0:00:21.990902 to create raster from points.
# Completed processing date 2020-12-22 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201222.tif
# ***** Completed processing date 2020-12-22 *****
# Processing date: 2020-12-23
# Next date for processing: 2020-12-24
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.503421 to query GFW API for Report.
# Elapsed time: 0:00:00.656115 to create dataframe.
# Elapsed time: 0:00:17.788518 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.592285 to create feature class.
# Completed processing date 2020-12-23 API to Feature Class.
# Elapsed time: 0:00:21.798179 to create raster from points.
# Completed processing date 2020-12-23 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201223.tif
# ***** Completed processing date 2020-12-23 *****
# Processing date: 2020-12-24
# Next date for processing: 2020-12-25
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:02.723285 to query GFW API for Report.
# Elapsed time: 0:00:00.515974 to create dataframe.
# Elapsed time: 0:00:13.502749 to create spatially enabled dataframe.
# Elapsed time: 0:00:06.937778 to create feature class.
# Completed processing date 2020-12-24 API to Feature Class.
# Elapsed time: 0:00:22.055387 to create raster from points.
# Completed processing date 2020-12-24 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201224.tif
# ***** Completed processing date 2020-12-24 *****
# Processing date: 2020-12-25
# Next date for processing: 2020-12-26
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.021488 to query GFW API for Report.
# Elapsed time: 0:00:00.495439 to create dataframe.
# Elapsed time: 0:00:13.374009 to create spatially enabled dataframe.
# Elapsed time: 0:00:07.024349 to create feature class.
# Completed processing date 2020-12-25 API to Feature Class.
# Elapsed time: 0:00:22.251803 to create raster from points.
# Completed processing date 2020-12-25 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201225.tif
# ***** Completed processing date 2020-12-25 *****
# Processing date: 2020-12-26
# Next date for processing: 2020-12-27
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.025719 to query GFW API for Report.
# Elapsed time: 0:00:00.639799 to create dataframe.
# Elapsed time: 0:00:17.580493 to create spatially enabled dataframe.
# Elapsed time: 0:00:08.427053 to create feature class.
# Completed processing date 2020-12-26 API to Feature Class.
# Elapsed time: 0:00:22.716611 to create raster from points.
# Completed processing date 2020-12-26 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201226.tif
# ***** Completed processing date 2020-12-26 *****
# Processing date: 2020-12-27
# Next date for processing: 2020-12-28
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.897470 to query GFW API for Report.
# Elapsed time: 0:00:00.735476 to create dataframe.
# Elapsed time: 0:00:19.515049 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.136322 to create feature class.
# Completed processing date 2020-12-27 API to Feature Class.
# Elapsed time: 0:00:22.655132 to create raster from points.
# Completed processing date 2020-12-27 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201227.tif
# ***** Completed processing date 2020-12-27 *****
# Processing date: 2020-12-28
# Next date for processing: 2020-12-29
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.589927 to query GFW API for Report.
# Elapsed time: 0:00:00.617165 to create dataframe.
# Elapsed time: 0:00:16.597954 to create spatially enabled dataframe.
# Elapsed time: 0:00:07.970157 to create feature class.
# Completed processing date 2020-12-28 API to Feature Class.
# Elapsed time: 0:00:22.408816 to create raster from points.
# Completed processing date 2020-12-28 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201228.tif
# ***** Completed processing date 2020-12-28 *****
# Processing date: 2020-12-29
# Next date for processing: 2020-12-30
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:02.980716 to query GFW API for Report.
# Elapsed time: 0:00:00.533275 to create dataframe.
# Elapsed time: 0:00:14.719959 to create spatially enabled dataframe.
# Elapsed time: 0:00:07.757928 to create feature class.
# Completed processing date 2020-12-29 API to Feature Class.
# Elapsed time: 0:00:22.622963 to create raster from points.
# Completed processing date 2020-12-29 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201229.tif
# ***** Completed processing date 2020-12-29 *****
# Processing date: 2020-12-30
# Next date for processing: 2020-12-31
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.858251 to query GFW API for Report.
# Elapsed time: 0:00:00.436903 to create dataframe.
# Elapsed time: 0:00:11.769347 to create spatially enabled dataframe.
# Elapsed time: 0:00:06.229735 to create feature class.
# Completed processing date 2020-12-30 API to Feature Class.
# Elapsed time: 0:00:21.955663 to create raster from points.
# Completed processing date 2020-12-30 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20201230.tif
# ***** Completed processing date 2020-12-30 *****
# ...
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:08.760718 to query GFW API for Report.
# Elapsed time: 0:00:00.802822 to create dataframe.
# Elapsed time: 0:00:22.016344 to create spatially enabled dataframe.
# Error processing date 2021-07-19: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210719]
# The table was not found. [fishing_effort_hours_daily_20210719]
# The table was not found. [fishing_effort_hours_daily_20210719]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-20
# Next date for processing: 2021-07-21
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.663272 to query GFW API for Report.
# Elapsed time: 0:00:00.846616 to create dataframe.
# Elapsed time: 0:00:22.106639 to create spatially enabled dataframe.
# Error processing date 2021-07-20: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210720]
# The table was not found. [fishing_effort_hours_daily_20210720]
# The table was not found. [fishing_effort_hours_daily_20210720]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-21
# Next date for processing: 2021-07-22
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.577789 to query GFW API for Report.
# Elapsed time: 0:00:00.835045 to create dataframe.
# Elapsed time: 0:00:22.567395 to create spatially enabled dataframe.
# Error processing date 2021-07-21: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210721]
# The table was not found. [fishing_effort_hours_daily_20210721]
# The table was not found. [fishing_effort_hours_daily_20210721]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-22
# Next date for processing: 2021-07-23
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.854924 to query GFW API for Report.
# Elapsed time: 0:00:00.791900 to create dataframe.
# Elapsed time: 0:00:21.552098 to create spatially enabled dataframe.
# Error processing date 2021-07-22: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210722]
# The table was not found. [fishing_effort_hours_daily_20210722]
# The table was not found. [fishing_effort_hours_daily_20210722]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-23
# Next date for processing: 2021-07-24
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.245363 to query GFW API for Report.
# Elapsed time: 0:00:00.726261 to create dataframe.
# Elapsed time: 0:00:19.261762 to create spatially enabled dataframe.
# Error processing date 2021-07-23: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210723]
# The table was not found. [fishing_effort_hours_daily_20210723]
# The table was not found. [fishing_effort_hours_daily_20210723]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-24
# Next date for processing: 2021-07-25
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.545901 to query GFW API for Report.
# Elapsed time: 0:00:00.649740 to create dataframe.
# Elapsed time: 0:00:17.466072 to create spatially enabled dataframe.
# Error processing date 2021-07-24: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210724]
# The table was not found. [fishing_effort_hours_daily_20210724]
# The table was not found. [fishing_effort_hours_daily_20210724]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-25
# Next date for processing: 2021-07-26
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.941886 to query GFW API for Report.
# Elapsed time: 0:00:00.663202 to create dataframe.
# Elapsed time: 0:00:17.835501 to create spatially enabled dataframe.
# Error processing date 2021-07-25: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210725]
# The table was not found. [fishing_effort_hours_daily_20210725]
# The table was not found. [fishing_effort_hours_daily_20210725]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-26
# Next date for processing: 2021-07-27
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.758482 to query GFW API for Report.
# Elapsed time: 0:00:00.780171 to create dataframe.
# Elapsed time: 0:00:21.756475 to create spatially enabled dataframe.
# Error processing date 2021-07-26: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210726]
# The table was not found. [fishing_effort_hours_daily_20210726]
# The table was not found. [fishing_effort_hours_daily_20210726]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-27
# Next date for processing: 2021-07-28
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.596806 to query GFW API for Report.
# Elapsed time: 0:00:00.865989 to create dataframe.
# Elapsed time: 0:00:22.366925 to create spatially enabled dataframe.
# Error processing date 2021-07-27: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210727]
# The table was not found. [fishing_effort_hours_daily_20210727]
# The table was not found. [fishing_effort_hours_daily_20210727]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-28
# Next date for processing: 2021-07-29
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.043324 to query GFW API for Report.
# Elapsed time: 0:00:00.802101 to create dataframe.
# Elapsed time: 0:00:22.500610 to create spatially enabled dataframe.
# Error processing date 2021-07-28: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210728]
# The table was not found. [fishing_effort_hours_daily_20210728]
# The table was not found. [fishing_effort_hours_daily_20210728]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-29
# Next date for processing: 2021-07-30
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.936856 to query GFW API for Report.
# Elapsed time: 0:00:00.800659 to create dataframe.
# Elapsed time: 0:00:21.854878 to create spatially enabled dataframe.
# Error processing date 2021-07-29: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210729]
# The table was not found. [fishing_effort_hours_daily_20210729]
# The table was not found. [fishing_effort_hours_daily_20210729]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-30
# Next date for processing: 2021-07-31
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.195072 to query GFW API for Report.
# Elapsed time: 0:00:00.672610 to create dataframe.
# Elapsed time: 0:00:18.432135 to create spatially enabled dataframe.
# Error processing date 2021-07-30: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210730]
# The table was not found. [fishing_effort_hours_daily_20210730]
# The table was not found. [fishing_effort_hours_daily_20210730]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-07-31
# Next date for processing: 2021-08-01
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.152917 to query GFW API for Report.
# Elapsed time: 0:00:00.633050 to create dataframe.
# Elapsed time: 0:00:17.002379 to create spatially enabled dataframe.
# Error processing date 2021-07-31: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210731]
# The table was not found. [fishing_effort_hours_daily_20210731]
# The table was not found. [fishing_effort_hours_daily_20210731]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-08-01
# Next date for processing: 2021-08-02
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.102066 to query GFW API for Report.
# Elapsed time: 0:00:00.660328 to create dataframe.
# Elapsed time: 0:00:17.500820 to create spatially enabled dataframe.
# Error processing date 2021-08-01: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210801]
# The table was not found. [fishing_effort_hours_daily_20210801]
# The table was not found. [fishing_effort_hours_daily_20210801]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-08-02
# Next date for processing: 2021-08-03
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.511713 to query GFW API for Report.
# Elapsed time: 0:00:00.762013 to create dataframe.
# Elapsed time: 0:00:20.983064 to create spatially enabled dataframe.
# Error processing date 2021-08-02: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210802]
# The table was not found. [fishing_effort_hours_daily_20210802]
# The table was not found. [fishing_effort_hours_daily_20210802]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-08-03
# Next date for processing: 2021-08-04
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.209314 to query GFW API for Report.
# Elapsed time: 0:00:00.873773 to create dataframe.
# Elapsed time: 0:00:22.453640 to create spatially enabled dataframe.
# Error processing date 2021-08-03: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210803]
# The table was not found. [fishing_effort_hours_daily_20210803]
# The table was not found. [fishing_effort_hours_daily_20210803]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-08-04
# Next date for processing: 2021-08-05
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.137751 to query GFW API for Report.
# Elapsed time: 0:00:00.798112 to create dataframe.
# Elapsed time: 0:00:22.355186 to create spatially enabled dataframe.
# Error processing date 2021-08-04: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210804]
# The table was not found. [fishing_effort_hours_daily_20210804]
# The table was not found. [fishing_effort_hours_daily_20210804]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-08-05
# Next date for processing: 2021-08-06
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:09.755399 to query GFW API for Report.
# Elapsed time: 0:00:00.835898 to create dataframe.
# Elapsed time: 0:00:21.086908 to create spatially enabled dataframe.
# Error processing date 2021-08-05: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210805]
# The table was not found. [fishing_effort_hours_daily_20210805]
# The table was not found. [fishing_effort_hours_daily_20210805]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-08-06
# Next date for processing: 2021-08-07
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.009842 to query GFW API for Report.
# Elapsed time: 0:00:00.699713 to create dataframe.
# Elapsed time: 0:00:18.181654 to create spatially enabled dataframe.
# Error processing date 2021-08-06: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210806]
# The table was not found. [fishing_effort_hours_daily_20210806]
# The table was not found. [fishing_effort_hours_daily_20210806]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-08-07
# Next date for processing: 2021-08-08
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.526034 to query GFW API for Report.
# Elapsed time: 0:00:00.666276 to create dataframe.
# Elapsed time: 0:00:17.689761 to create spatially enabled dataframe.
# Error processing date 2021-08-07: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# FDO error: -3 [fishing_effort_hours_daily_20210807]
# The table was not found. [fishing_effort_hours_daily_20210807]
# The table was not found. [fishing_effort_hours_daily_20210807]
# Failed to execute (CreateFeatureclass).
#
# Processing date: 2021-08-08
# Next date for processing: 2021-08-09
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.505209 to query GFW API for Report.
# Elapsed time: 0:00:00.759263 to create dataframe.
# Elapsed time: 0:00:18.910402 to create spatially enabled dataframe.
# Elapsed time: 0:00:09.695099 to create feature class.
# Completed processing date 2021-08-08 API to Feature Class.
# Elapsed time: 0:00:22.494472 to create raster from points.
# Completed processing date 2021-08-08 Point to Raster.
# Deleted intermediate raster: D:\temp\gfw\fishing_effort_hours_daily\fishing_effort_hours_daily_20210808.tif
# ***** Completed processing date 2021-08-08 *****
# Processing date: 2021-08-09
# Next date for processing: 2021-08-10
# Waiting 5 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.958729 to query GFW API for Report.
# Elapsed time: 0:00:01.030322 to create dataframe.

# %%
tif_files = [f for f in os.listdir(output_raster_workspace) if f.endswith('.tif')]
print(tif_files)

# %%
md_path = f"{workspace}/{gdb_name}/{product_name}"
if not arcpy.Exists(md_path):
    arcpy.CreateMosaicDataset_management(
        in_workspace=f"{workspace}/{gdb_name}",
        in_mosaicdataset_name=product_name,
        coordinate_system=4326
    )
print(f"Mosaic dataset '{product_name}' created in {gdb_name}")

# %%
arcpy.management.AddRastersToMosaicDataset(
    in_mosaic_dataset=f"{gdb_name}/{product_name}",
    raster_type="Raster Dataset",
    input_path=output_raster_workspace,
    update_cellsize_ranges="UPDATE_CELL_SIZES",
    update_boundary="UPDATE_BOUNDARY",
    update_overviews="NO_OVERVIEWS",
    maximum_pyramid_levels=None,
    maximum_cell_size=0,
    minimum_dimension=1500,
    spatial_reference=None,
    filter="*.TIF",
    sub_folder="NO_SUBFOLDERS",
    duplicate_items_action="EXCLUDE_DUPLICATES",
    build_pyramids="NO_PYRAMIDS",
    calculate_statistics="NO_STATISTICS",
    build_thumbnails="NO_THUMBNAILS",
    operation_description="",
    force_spatial_reference="NO_FORCE_SPATIAL_REFERENCE",
    estimate_statistics="NO_STATISTICS",
    aux_inputs=None,
    enable_pixel_cache="NO_PIXEL_CACHE",
    cache_location=workspace
)

# %%
arcpy.management.CalculateField(
    in_table=f"{gdb_name}/{product_name}",
    field="date_text",
    expression='!Name!.split("_")[4]',
    expression_type="PYTHON3",
    code_block="",
    field_type="TEXT",
    enforce_domains="NO_ENFORCE_DOMAINS"
)

# %%
arcpy.management.CalculateField(
    in_table=f"{gdb_name}/{product_name}",
    field="sar_date",
    expression='str(!date_text!)[4:6] + "/" + str(!date_text!)[6:8] + "/" + str(!date_text!)[:4]',
    expression_type="PYTHON3",
    code_block="",
    field_type="DATE",
    enforce_domains="NO_ENFORCE_DOMAINS"
)

# %%
arcpy.management.CalculateField(
    in_table=f"{gdb_name}/{product_name}",
    field="variable_mapped",
    expression=f'"{variable_name}"',
    expression_type="PYTHON3",
    code_block="",
    field_type="TEXT",
    enforce_domains="NO_ENFORCE_DOMAINS"
)

# %%
arcpy.md.BuildMultidimensionalInfo(
    in_mosaic_dataset=f"{gdb_name}/{product_name}",
    variable_field="variable_mapped",
    dimension_fields="sar_date date days",
    variable_desc_units="'SAR Detections' 'SAR Detections' count",
    delete_multidimensional_info="NO_DELETE_MULTIDIMENSIONAL_INFO"
)

# %%
arcpy.management.SetMosaicDatasetProperties(
    in_mosaic_dataset=f"{gdb_name}/{product_name}",
    rows_maximum_imagesize=4100,
    columns_maximum_imagesize=15000,
    allowed_compressions="None;JPEG;LZ77;LERC",
    default_compression_type="None",
    JPEG_quality=75,
    LERC_Tolerance=0.01,
    resampling_type="NEAREST",
    clip_to_footprints="NOT_CLIP",
    footprints_may_contain_nodata="FOOTPRINTS_MAY_CONTAIN_NODATA",
    clip_to_boundary="CLIP",
    color_correction="NOT_APPLY",
    allowed_mensuration_capabilities="Basic",
    default_mensuration_capabilities="Basic",
    allowed_mosaic_methods="ByAttribute;NorthWest;Center;LockRaster;Nadir;Viewpoint;Seamline;None",
    default_mosaic_method="ByAttribute",
    order_field="StdTime",
    order_base="",
    sorting_order="DESCENDING",
    mosaic_operator="FIRST",
    blend_width=10,
    view_point_x=600,
    view_point_y=300,
    max_num_per_mosaic=20,
    cell_size_tolerance=0.8,
    cell_size="0 0",
    metadata_level="Basic",
    transmission_fields="Name;MinPS;MaxPS;LowPS;HighPS;Tag;GroupName;ProductName;CenterX;CenterY;ZOrder;Shape_Length;Shape_Area;StdTime;Dimensions;Variable",
    use_time="ENABLED",
    start_time_field="StdTime",
    end_time_field="StdTime",
    time_format="YYYY/MM/DD",
    geographic_transform=None,
    max_num_of_download_items=20,
    max_num_of_records_returned=1000,
    data_source_type="GENERIC",
    minimum_pixel_contribution=1,
    processing_templates=f"None;'{variable_name}'",
    default_processing_template="None",
    time_interval=1,
    time_interval_units="Days",
    product_definition="NONE",
    product_band_definitions=None
)

# %%
crf_path = os.path.join(workspace, product_name + ".crf")

with arcpy.EnvManager(parallelProcessingFactor="90%"):
    arcpy.management.CopyRaster(
        in_raster=f"{gdb_name}/{product_name}",
        out_rasterdataset=crf_path,
        config_keyword="",
        background_value=None,
        nodata_value="",
        onebit_to_eightbit="NONE",
        colormap_to_RGB="NONE",
        pixel_type="",
        scale_pixel_value="NONE",
        RGB_to_Colormap="NONE",
        format="CRF",
        transform="NONE",
        process_as_multidimensional="ALL_SLICES",
        build_multidimensional_transpose="TRANSPOSE"
    )

# %%
with arcpy.EnvManager(parallelProcessingFactor="90%"):
    out_multidimensional_raster = arcpy.ia.AggregateMultidimensionalRaster(
        in_multidimensional_raster=crf_path,
        dimension="StdTime",
        aggregation_method="SUM",
        variables=f'"{variable_name}"',
        aggregation_def="INTERVAL_KEYWORD",
        interval_keyword="MONTHLY",
        interval_value=None,
        interval_unit="",
        interval_ranges=None,
        aggregation_function="",
        ignore_nodata="DATA",
        dimensionless="DIMENSIONS",
        percentile_value=90,
        percentile_interpolation_type="NEAREST"
    )
    out_multidimensional_raster.save(crf_path.replace('daily','monthly'))

# %%
with arcpy.EnvManager(parallelProcessingFactor="90%"):
    out_multidimensional_raster = arcpy.ia.AggregateMultidimensionalRaster(
        in_multidimensional_raster=crf_path,
        dimension="StdTime",
        aggregation_method="SUM",
        variables=f'"{variable_name}"',
        aggregation_def="INTERVAL_KEYWORD",
        interval_keyword="YEARLY",
        interval_value=None,
        interval_unit="",
        interval_ranges=None,
        aggregation_function="",
        ignore_nodata="DATA",
        dimensionless="DIMENSIONS",
        percentile_value=90,
        percentile_interpolation_type="NEAREST"
    )
    out_multidimensional_raster.save(crf_path.replace('daily','annual'))

# %%
# Pause and ask the user whether to continue
while True:
    resp = input("Continue processing the notebook? [y/N]: ").strip().lower()
    if resp in ("y", "yes"):
        user_continue = True
        print("Continuing notebook execution...")
        break
    if resp in ("n", "no", ""):
        user_continue = False
        print("Notebook execution halted by user. Set 'user_continue = False'.")
        raise SystemExit("Execution stopped by user.")
    print("Please answer 'y' or 'n'.")

# %%
def overwrite_til(til_item, ras):
    copy_raster_op_til = analytics.copy_raster(
        # input_raster=os.path.join(data_dir, ras),
        input_raster=ras,
        output_name=tiled_img_item,
        tiles_only=True,
        gis=gis
    )
    return copy_raster_op_til

# %%
# search by title
items_by_title = gis.content.search(query=f'title:"{product_name}"', max_items=100)

if items_by_title:
    print("Found items by title:")
    for it in items_by_title:
        print(it.title, it.id, it.type, it.owner, it.url if hasattr(it, 'url') else "")
        tiled_img_item = gis.content.get(it.id)
        tiled_img_item
        in_ras = data_url
        result = None
        if arcpy.Exists(in_ras):
            print(f"Dataset exists: {in_ras} ...overwriting Imagery Layer")
            result = overwrite_til(tiled_img_item, in_ras)
        else:
            print(f"Dataset does not exist: {in_ras}")

if not items_by_title:
    print(f"No items found for '{product_name}' - creating Imagery Layer")
    data_url = crf_path
    print(data_url)

    ImageryLayer = copy_raster(input_raster=data_url,
                               output_name=product_name,
                               gis=gis)
    ImageryLayer
