# %%
from arcgis.gis import GIS
import platform
import psutil
import sys
import os
import shutil
import datetime
import time
from datetime import date, timedelta
import pandas as pd
import arcpy
from arcgis.features import GeoAccessor
import arcgis
from arcgis.raster import *
from arcgis.raster.analytics import *

arcgis.env.verbose=True

# %%
sys.path.append(r'C:\GitHub\code-base')
# from agol_credentials import kv_oceans_username, kv_oceans_password, kv_oceans_org
from agol_credentials import esri_oceans_username, esri_oceans_password, esri_oceans_org
gis = GIS(esri_oceans_org, esri_oceans_username, esri_oceans_password, verify_cert=True)
gis
# Out:
# GIS @ https://esri.maps.arcgis.com version:2025.2

# %%
print("**********Platform information**********")
print(f"System: {platform.system()}")
print(f"Node Name: {platform.node()}")
print(f"Release: {platform.release()}")
print(f"Version: {platform.version()}")
print(f"Machine: {platform.machine()}")
print(f"Processor: {platform.processor()}")
print("Memory information:")
mem = psutil.virtual_memory()
print(f"Total: {mem.total / (1024 ** 3):.2f} GB")
print(f"Available: {mem.available / (1024 ** 3):.2f} GB")
print(f"Used: {mem.used / (1024 ** 3):.2f} GB")
print(f"Percentage: {mem.percent}%")
print("CPU information:")
print(f"Physical cores: {psutil.cpu_count(logical=False)}")
print("**********Platform information**********")
# Out:
# **********Platform information**********
# System: Windows
# Node Name: KVanGraaf
# Release: 10
# Version: 10.0.22631
# Machine: AMD64
# Processor: Intel64 Family 6 Model 85 Stepping 7, GenuineIntel
# Memory information:
# Total: 127.69 GB
# Available: 88.31 GB
# Used: 39.38 GB
# Percentage: 30.8%
# CPU information:
# Physical cores: 18
# **********Platform information**********

# %%
# gfwapi_path = '/arcgis/home/gfwapiclient'
# if not os.path.isdir(gfwapi_path):
#     %pip install --target /arcgis/home/gfwapiclient gfw-api-python-client
#     # %pip install gfw-api-python-client
#     # %pip install --upgrade gfw-api-python-client

# %%
# sys.path.append(gfwapi_path)
import gfwapiclient as gfw
# Out:
# c:\Users\keit8223\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone_v2\Lib\site-packages\pyproj\__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
# sys.path.append('/arcgis/home/notebook/gfw')
from access_credentials import access_token_key

# %%
# workspace = "/arcgis/home/notebook/gfw"
workspace = r"C:\temp\gfw"
arcpy.env.workspace = workspace
arcpy.env.overwriteOutput = True

if not os.path.exists(workspace):
    os.makedirs(workspace)

# %%
access_token = os.environ.get(
    "GFW_API_ACCESS_TOKEN",
    access_token_key,
)

gfw_client = gfw.Client(
    access_token=access_token,
)

# %%
# Explore GFW Client Fourwings capabilities
print("=== GFW Client Fourwings Methods ===")
fourwings_methods = [method for method in dir(gfw_client.fourwings) if not method.startswith('_')]
for method in fourwings_methods:
    print(f"- {method}")

print("\n=== Create Report Method Details ===")
# Get help for create_report method
help(gfw_client.fourwings.create_report)

print("\n=== Fourwings Object Type ===")
print(type(gfw_client.fourwings))

# You can also check the docstring
print("\n=== Create Report Docstring ===")
print(gfw_client.fourwings.create_report.__doc__)

# Inspect the method signature
import inspect
print("\n=== Create Report Method Signature ===")
signature = inspect.signature(gfw_client.fourwings.create_report)
print(f"Parameters: {signature}")
for param_name, param in signature.parameters.items():
    print(f"  - {param_name}: {param.annotation if param.annotation != inspect.Parameter.empty else 'No type hint'}")
    if param.default != inspect.Parameter.empty:
        print(f"    Default: {param.default}")
# Out:
# === GFW Client Fourwings Methods ===
# - create_ais_presence_report
# - create_fishing_effort_report
# - create_report
# - create_sar_presence_report
#
# === Create Report Method Details ===
# Help on method create_report in module gfwapiclient.resources.fourwings.resources:
#
# async create_report(*, spatial_resolution: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportSpatialResolution, str, NoneType] = None, group_by: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportGroupBy, str, NoneType] = None, temporal_resolution: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportTemporalResolution, str, NoneType] = None, datasets: Union[List[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportDataset], List[str], NoneType] = None, filters: Optional[List[str]] = None, start_date: Union[datetime.date, str, NoneType] = None, end_date: Union[datetime.date, str, NoneType] = None, spatial_aggregation: Optional[bool] = None, geojson: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsGeometry, Dict[str, Any], NoneType] = None, region: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportRegion, Dict[str, Any], NoneType] = None, **kwargs: Dict[str, Any]) -> gfwapiclient.resources.fourwings.report.models.response.FourWingsReportResult method of gfwapiclient.resources.fourwings.resources.FourWingsResource instance
#     Create 4Wings report for a specified region.
#
#     Generates a report from the 4Wings API based on the provided parameters.
#
#     Generated report can serves following analytical needs:
#
#     - Fisheries compliance monitoring
#     - Fleet management
#     - Supply chain visibility
#     - Port traffic analysis
#     - Fleet management
#     - Supply chain visibility
#     - Dark vessel detection
#     - Remote area surveillance
#
#     For more details on the 4Wings data caveats, please refer to the official
#     Global Fishing Watch API documentation:
#
#     See: https://globalfishingwatch.org/our-apis/documentation#apparent-fishing-effort
#
#     See: https://globalfishingwatch.org/our-apis/documentation#sar-vessel-detections-data-caveats
#
#     See: https://globalfishingwatch.org/our-apis/documentation#ais-vessel-presence-caveats
#
#     **Disclaimer:**
#
#     AIS vessel presence is one of the largest datasets available. To prevent timeouts
#     and ensure optimal performance, keep requests manageable: prefer simple, small
#     regions and shorter time ranges (e.g., a few days).
#
#     Args:
#         spatial_resolution (Optional[Union[FourWingsReportSpatialResolution, str]], default="HIGH"):
#             Spatial resolution of the report. Defaults to `"HIGH"`.
#             Allowed values: `"HIGH"`, `"LOW"`.
#             Example: `"HIGH"`.
#
#         group_by (Optional[Union[FourWingsReportGroupBy, str]], default=None):
#             Grouping criteria for the report. Defaults to `None`.
#             Allowed values: `"VESSEL_ID"`, `"FLAG"`, `"GEARTYPE"`, `"FLAGANDGEARTYPE"`, `"MMSI"`.
#             Example: `"FLAG"`.
#
#         temporal_resolution (Optional[Union[FourWingsReportTemporalResolution, str]], default="HOURLY"):
#             Temporal resolution of the report. Defaults to `"HOURLY"`
#             Allowed values: `"HOURLY"`, `"DAILY"`, `"MONTHLY"`, `"YEARLY"`, `"ENTIRE"`.
#             Example: `"HOURLY"`.
#
#         datasets (Optional[Union[List[FourWingsReportDataset], List[str]]], default=["public-global-fishing-effort:latest"]):
#             Datasets that will be used to create the report. Defaults to `["public-global-fishing-effort:latest"]`.
#             Allowed values: `"public-global-fishing-effort:latest"`, `"public-global-sar-presence:latest"`,
#             `"public-global-presence:latest"`.
#             Example: `["public-global-fishing-effort:latest"]`.
#
#         filters (Optional[List[str]], default=None):
#             Filters to apply to the report. Defaults to `None`.
#             Example: `["flag in ('ESP', 'FRA')"]`.
#
#         start_date (Optional[Union[datetime.date, str]], default=None):
#             Start date for the report. Used to build `date_range`. Defaults to `None`.
#             Allowed values: A string in `ISO 8601 format` or `datetime.date` instance.
#             Example: `datetime.date(2021, 1, 1)` or `"2021-01-01"`.
#
#         end_date (Optional[Union[datetime.date, str]], default=None):
#             End date for the report. Used to build `date_range`. Defaults to `None`.
#             Allowed values: A string in `ISO 8601 format` or `datetime.date` instance.
#             Example: `datetime.date(2021, 1, 15)` or `"2021-01-15"`.
#
#         spatial_aggregation (Optional[bool], default=None):
#             Whether to spatially aggregate the report. Defaults to `None`.
#             Example: `True`.
#
#         geojson (Optional[Union[FourWingsGeometry, Dict[str, Any]]], default=None):
#             Custom GeoJSON geometry to filter the report. Defaults to `None`.
#             Example: `{"type": "Polygon", "coordinates": [...]}`.
#
#         region (Optional[Union[FourWingsReportRegion, Dict[str, Any]]], default=None):
#             Predefined region information to filter the report. Defaults to `None`.
#             Example: `{"dataset": "public-eez-areas", "id": "5690"}`.
#
#         **kwargs (Dict[str, Any]):
#             Additional keyword arguments.
#
#     Returns:
#         FourWingsReportResult:
#             The generated 4Wings report.
#
#     Raises:
#         GFWAPIClientError:
#             If the API request fails.
#
#         RequestParamsValidationError:
#             If the request parameters are invalid.
#
#         RequestBodyValidationError:
#             If the request body is invalid.
#
#
# === Fourwings Object Type ===
# <class 'gfwapiclient.resources.fourwings.resources.FourWingsResource'>
#
# === Create Report Docstring ===
# Create 4Wings report for a specified region.
#
#         Generates a report from the 4Wings API based on the provided parameters.
#
#         Generated report can serves following analytical needs:
#
#         - Fisheries compliance monitoring
#         - Fleet management
#         - Supply chain visibility
#         - Port traffic analysis
#         - Fleet management
#         - Supply chain visibility
#         - Dark vessel detection
#         - Remote area surveillance
#
#         For more details on the 4Wings data caveats, please refer to the official
#         Global Fishing Watch API documentation:
#
#         See: https://globalfishingwatch.org/our-apis/documentation#apparent-fishing-effort
#
#         See: https://globalfishingwatch.org/our-apis/documentation#sar-vessel-detections-data-caveats
#
#         See: https://globalfishingwatch.org/our-apis/documentation#ais-vessel-presence-caveats
#
#         **Disclaimer:**
#
#         AIS vessel presence is one of the largest datasets available. To prevent timeouts
#         and ensure optimal performance, keep requests manageable: prefer simple, small
#         regions and shorter time ranges (e.g., a few days).
#
#         Args:
#             spatial_resolution (Optional[Union[FourWingsReportSpatialResolution, str]], default="HIGH"):
#                 Spatial resolution of the report. Defaults to `"HIGH"`.
#                 Allowed values: `"HIGH"`, `"LOW"`.
#                 Example: `"HIGH"`.
#
#             group_by (Optional[Union[FourWingsReportGroupBy, str]], default=None):
#                 Grouping criteria for the report. Defaults to `None`.
#                 Allowed values: `"VESSEL_ID"`, `"FLAG"`, `"GEARTYPE"`, `"FLAGANDGEARTYPE"`, `"MMSI"`.
#                 Example: `"FLAG"`.
#
#             temporal_resolution (Optional[Union[FourWingsReportTemporalResolution, str]], default="HOURLY"):
#                 Temporal resolution of the report. Defaults to `"HOURLY"`
#                 Allowed values: `"HOURLY"`, `"DAILY"`, `"MONTHLY"`, `"YEARLY"`, `"ENTIRE"`.
#                 Example: `"HOURLY"`.
#
#             datasets (Optional[Union[List[FourWingsReportDataset], List[str]]], default=["public-global-fishing-effort:latest"]):
#                 Datasets that will be used to create the report. Defaults to `["public-global-fishing-effort:latest"]`.
#                 Allowed values: `"public-global-fishing-effort:latest"`, `"public-global-sar-presence:latest"`,
#                 `"public-global-presence:latest"`.
#                 Example: `["public-global-fishing-effort:latest"]`.
#
#             filters (Optional[List[str]], default=None):
#                 Filters to apply to the report. Defaults to `None`.
#                 Example: `["flag in ('ESP', 'FRA')"]`.
#
#             start_date (Optional[Union[datetime.date, str]], default=None):
#                 Start date for the report. Used to build `date_range`. Defaults to `None`.
#                 Allowed values: A string in `ISO 8601 format` or `datetime.date` instance.
#                 Example: `datetime.date(2021, 1, 1)` or `"2021-01-01"`.
#
#             end_date (Optional[Union[datetime.date, str]], default=None):
#                 End date for the report. Used to build `date_range`. Defaults to `None`.
#                 Allowed values: A string in `ISO 8601 format` or `datetime.date` instance.
#                 Example: `datetime.date(2021, 1, 15)` or `"2021-01-15"`.
#
#             spatial_aggregation (Optional[bool], default=None):
#                 Whether to spatially aggregate the report. Defaults to `None`.
#                 Example: `True`.
#
#             geojson (Optional[Union[FourWingsGeometry, Dict[str, Any]]], default=None):
#                 Custom GeoJSON geometry to filter the report. Defaults to `None`.
#                 Example: `{"type": "Polygon", "coordinates": [...]}`.
#
#             region (Optional[Union[FourWingsReportRegion, Dict[str, Any]]], default=None):
#                 Predefined region information to filter the report. Defaults to `None`.
#                 Example: `{"dataset": "public-eez-areas", "id": "5690"}`.
#
#             **kwargs (Dict[str, Any]):
#                 Additional keyword arguments.
#
#         Returns:
#             FourWingsReportResult:
#                 The generated 4Wings report.
#
#         Raises:
#             GFWAPIClientError:
#                 If the API request fails.
#
#             RequestParamsValidationError:
#                 If the request parameters are invalid.
#
#             RequestBodyValidationError:
#                 If the request body is invalid.
#
#
# === Create Report Method Signature ===
# Parameters: (*, spatial_resolution: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportSpatialResolution, str, NoneType] = None, group_by: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportGroupBy, str, NoneType] = None, temporal_resolution: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportTemporalResolution, str, NoneType] = None, datasets: Union[List[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportDataset], List[str], NoneType] = None, filters: Optional[List[str]] = None, start_date: Union[datetime.date, str, NoneType] = None, end_date: Union[datetime.date, str, NoneType] = None, spatial_aggregation: Optional[bool] = None, geojson: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsGeometry, Dict[str, Any], NoneType] = None, region: Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportRegion, Dict[str, Any], NoneType] = None, **kwargs: Dict[str, Any]) -> gfwapiclient.resources.fourwings.report.models.response.FourWingsReportResult
#   - spatial_resolution: typing.Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportSpatialResolution, str, NoneType]
#     Default: None
#   - group_by: typing.Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportGroupBy, str, NoneType]
#     Default: None
#   - temporal_resolution: typing.Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportTemporalResolution, str, NoneType]
#     Default: None
#   - datasets: typing.Union[typing.List[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportDataset], typing.List[str], NoneType]
#     Default: None
#   - filters: typing.Optional[typing.List[str]]
#     Default: None
#   - start_date: typing.Union[datetime.date, str, NoneType]
#     Default: None
#   - end_date: typing.Union[datetime.date, str, NoneType]
#     Default: None
#   - spatial_aggregation: typing.Optional[bool]
#     Default: None
#   - geojson: typing.Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsGeometry, typing.Dict[str, typing.Any], NoneType]
#     Default: None
#   - region: typing.Union[gfwapiclient.resources.fourwings.report.models.request.FourWingsReportRegion, typing.Dict[str, typing.Any], NoneType]
#     Default: None
#   - kwargs: typing.Dict[str, typing.Any]

# %%
global_geojson = {"type": "Polygon", "coordinates": [[[180, 90], [180, -90], [-180, -90], [-180, 90], [180, 90]]]}

# %% [markdown]
# ### ***** User Input *****

# %%
start = date(2020, 1, 1)
end = date.today()
product_name = "sar_detection_daily_matched" ### keep it to four words (separated by underscores "_")
gfw_constant_raster = r"data/gfw_constant_raster.tif"
variable_name = "SAR Detection - Matched"

# %%
date_list = []
d = start
while d <= end:
    date_list.append(d.strftime("%Y-%m-%d"))
    d += timedelta(days=1)

# %%
gdb_name = "gfw_" + product_name + ".gdb"
if not arcpy.Exists(gdb_name):
    arcpy.CreateFileGDB_management(workspace, gdb_name)

output_raster_workspace = os.path.join(workspace, product_name)
if not os.path.exists(output_raster_workspace):
    os.makedirs(output_raster_workspace)

# %%
for current_date in date_list:
    print(f"Processing date: {current_date}")
    date_name = current_date.replace("-", "")
    next_date = (pd.to_datetime(current_date) + pd.Timedelta(days=1)).strftime("%Y-%m-%d")
    print(f"Next date for processing: {next_date}")
    feature_class = os.path.join(workspace, gdb_name, product_name + "_" + str(date_name))
    if arcpy.Exists(feature_class):
        print(f"Feature class {feature_class} already exists. Skipping.")
        continue
    try:
        print("Waiting 10 seconds to eliminate too many requests error...")
        time.sleep(10)
        dt_start = datetime.now()
        var_name_lower = variable_name.lower()
        if "unmatched" in var_name_lower:
            matched_param = 'false'
        elif "matched" in var_name_lower:
            matched_param = 'true'
        else:
            matched_param = 'true'  # default

        gfw_report = await gfw_client.fourwings.create_report(
            datasets=["public-global-sar-presence:latest"],
            spatial_resolution="HIGH",
            temporal_resolution="DAILY",
            group_by="GEARTYPE",
            matched=matched_param,
            start_date=current_date,
            end_date=next_date,
            geojson=global_geojson,
        )
        dt_api = datetime.now()
        print(f"Elapsed time: {dt_api - dt_start} to query GFW API for Report.")
        gfw_report_df = gfw_report.df()
        gfw_report_df['lat'] = gfw_report_df['lat'] + 0.005
        gfw_report_df['lon'] = gfw_report_df['lon'] + 0.005
        dt_dataframe = datetime.now()
        print(f"Elapsed time: {dt_dataframe - dt_api} to create dataframe.")
        gfw_sedf = pd.DataFrame.spatial.from_xy(df = gfw_report_df, x_column = "lon", y_column = "lat", sr=4326)
        dt_sdef = datetime.now()
        print(f"Elapsed time: {dt_sdef - dt_api} to create spatially enabled dataframe.")
        gfw_sedf.spatial.to_featureclass(feature_class)
        dt_fc = datetime.now()
        print(f"Elapsed time: {dt_fc - dt_sdef} to create feature class.")
        print(f"Completed processing date {current_date} API to Feature Class.")

        output_raster = os.path.join(output_raster_workspace, product_name + '_' + str(date_name) + ".tif")
        
        arcpy.conversion.PointToRaster(
            in_features=feature_class,
            value_field="detections",
            out_rasterdataset=output_raster,
            cell_assignment="SUM",
            priority_field="NONE",
            cellsize=0.01,  # adjust cell size as needed 0.1 for LOW and 0.01 for HIGH
            build_rat="BUILD"
        )

        dt_ras = datetime.now()
        print(f"Elapsed time: {dt_ras - dt_fc} to create raster from points.")
        print(f"Completed processing date {current_date} Point to Raster.")

        
        final_raster = os.path.join(output_raster_workspace, product_name + '_' + str(date_name) + "_global.tif")
        with arcpy.EnvManager(outputCoordinateSystem='GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]]',
                              snapRaster=gfw_constant_raster, cellSize=gfw_constant_raster, extent=gfw_constant_raster):
            global_raster = arcpy.sa.Plus(
                in_raster_or_constant1=output_raster,
                in_raster_or_constant2=gfw_constant_raster
            )
            global_raster.save(final_raster)
        
        arcpy.management.Delete(output_raster)
        print(f"Deleted intermediate raster: {output_raster}")

        print(f"***** Completed processing date {current_date} *****")
    except Exception as e:
        print(f"Error processing date {current_date}: {e}")
# Out:
# Processing date: 2020-01-01
# Next date for processing: 2020-01-02
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:00.617058 to query GFW API for Report.
# Elapsed time: 0:00:00.123516 to create dataframe.
# Elapsed time: 0:00:00.617058 to query GFW API for Report.
# Elapsed time: 0:00:00.123516 to create dataframe.
# Elapsed time: 0:00:03.729216 to create spatially enabled dataframe.
# Elapsed time: 0:00:03.729216 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.920086 to create feature class.
# Completed processing date 2020-01-01 API to Feature Class.
# Elapsed time: 0:00:02.920086 to create feature class.
# Completed processing date 2020-01-01 API to Feature Class.
# Elapsed time: 0:00:07.589334 to create raster from points.
# Completed processing date 2020-01-01 Point to Raster.
# Elapsed time: 0:00:07.589334 to create raster from points.
# Completed processing date 2020-01-01 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200101.tif
# ***** Completed processing date 2020-01-01 *****
# Processing date: 2020-01-02
# Next date for processing: 2020-01-03
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200101.tif
# ***** Completed processing date 2020-01-01 *****
# Processing date: 2020-01-02
# Next date for processing: 2020-01-03
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.030814 to query GFW API for Report.
# Elapsed time: 0:00:00.094514 to create dataframe.
# Elapsed time: 0:00:06.030814 to query GFW API for Report.
# Elapsed time: 0:00:00.094514 to create dataframe.
# Elapsed time: 0:00:02.807747 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.807747 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.529058 to create feature class.
# Completed processing date 2020-01-02 API to Feature Class.
# Elapsed time: 0:00:02.529058 to create feature class.
# Completed processing date 2020-01-02 API to Feature Class.
# Elapsed time: 0:00:07.260529 to create raster from points.
# Completed processing date 2020-01-02 Point to Raster.
# Elapsed time: 0:00:07.260529 to create raster from points.
# Completed processing date 2020-01-02 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200102.tif
# ***** Completed processing date 2020-01-02 *****
# Processing date: 2020-01-03
# Next date for processing: 2020-01-04
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200102.tif
# ***** Completed processing date 2020-01-02 *****
# Processing date: 2020-01-03
# Next date for processing: 2020-01-04
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.441935 to query GFW API for Report.
# Elapsed time: 0:00:00.064517 to create dataframe.
# Elapsed time: 0:00:03.441935 to query GFW API for Report.
# Elapsed time: 0:00:00.064517 to create dataframe.
# Elapsed time: 0:00:01.915450 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.915450 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.119286 to create feature class.
# Completed processing date 2020-01-03 API to Feature Class.
# Elapsed time: 0:00:02.119286 to create feature class.
# Completed processing date 2020-01-03 API to Feature Class.
# Elapsed time: 0:00:06.883720 to create raster from points.
# Completed processing date 2020-01-03 Point to Raster.
# Elapsed time: 0:00:06.883720 to create raster from points.
# Completed processing date 2020-01-03 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200103.tif
# ***** Completed processing date 2020-01-03 *****
# Processing date: 2020-01-04
# Next date for processing: 2020-01-05
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200103.tif
# ***** Completed processing date 2020-01-03 *****
# Processing date: 2020-01-04
# Next date for processing: 2020-01-05
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.738433 to query GFW API for Report.
# Elapsed time: 0:00:00.073588 to create dataframe.
# Elapsed time: 0:00:01.738433 to query GFW API for Report.
# Elapsed time: 0:00:00.073588 to create dataframe.
# Elapsed time: 0:00:02.176588 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.176588 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.369485 to create feature class.
# Completed processing date 2020-01-04 API to Feature Class.
# Elapsed time: 0:00:02.369485 to create feature class.
# Completed processing date 2020-01-04 API to Feature Class.
# Elapsed time: 0:00:07.409457 to create raster from points.
# Completed processing date 2020-01-04 Point to Raster.
# Elapsed time: 0:00:07.409457 to create raster from points.
# Completed processing date 2020-01-04 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200104.tif
# ***** Completed processing date 2020-01-04 *****
# Processing date: 2020-01-05
# Next date for processing: 2020-01-06
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200104.tif
# ***** Completed processing date 2020-01-04 *****
# Processing date: 2020-01-05
# Next date for processing: 2020-01-06
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:02.244810 to query GFW API for Report.
# Elapsed time: 0:00:00.078003 to create dataframe.
# Elapsed time: 0:00:02.244810 to query GFW API for Report.
# Elapsed time: 0:00:00.078003 to create dataframe.
# Elapsed time: 0:00:02.435629 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.435629 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.336630 to create feature class.
# Completed processing date 2020-01-05 API to Feature Class.
# Elapsed time: 0:00:02.336630 to create feature class.
# Completed processing date 2020-01-05 API to Feature Class.
# Elapsed time: 0:00:07.773028 to create raster from points.
# Completed processing date 2020-01-05 Point to Raster.
# Elapsed time: 0:00:07.773028 to create raster from points.
# Completed processing date 2020-01-05 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200105.tif
# ***** Completed processing date 2020-01-05 *****
# Processing date: 2020-01-06
# Next date for processing: 2020-01-07
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200105.tif
# ***** Completed processing date 2020-01-05 *****
# Processing date: 2020-01-06
# Next date for processing: 2020-01-07
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.152273 to query GFW API for Report.
# Elapsed time: 0:00:00.076512 to create dataframe.
# Elapsed time: 0:00:03.152273 to query GFW API for Report.
# Elapsed time: 0:00:00.076512 to create dataframe.
# Elapsed time: 0:00:02.261772 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.261772 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.346707 to create feature class.
# Completed processing date 2020-01-06 API to Feature Class.
# Elapsed time: 0:00:02.346707 to create feature class.
# Completed processing date 2020-01-06 API to Feature Class.
# Elapsed time: 0:00:07.372220 to create raster from points.
# Completed processing date 2020-01-06 Point to Raster.
# Elapsed time: 0:00:07.372220 to create raster from points.
# Completed processing date 2020-01-06 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200106.tif
# ***** Completed processing date 2020-01-06 *****
# Processing date: 2020-01-07
# Next date for processing: 2020-01-08
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200106.tif
# ***** Completed processing date 2020-01-06 *****
# Processing date: 2020-01-07
# Next date for processing: 2020-01-08
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:02.094337 to query GFW API for Report.
# Elapsed time: 0:00:00.102473 to create dataframe.
# Elapsed time: 0:00:02.094337 to query GFW API for Report.
# Elapsed time: 0:00:00.102473 to create dataframe.
# Elapsed time: 0:00:02.958778 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.958778 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.575323 to create feature class.
# Completed processing date 2020-01-07 API to Feature Class.
# Elapsed time: 0:00:02.575323 to create feature class.
# Completed processing date 2020-01-07 API to Feature Class.
# Elapsed time: 0:00:07.242681 to create raster from points.
# Completed processing date 2020-01-07 Point to Raster.
# Elapsed time: 0:00:07.242681 to create raster from points.
# Completed processing date 2020-01-07 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200107.tif
# ***** Completed processing date 2020-01-07 *****
# Processing date: 2020-01-08
# Next date for processing: 2020-01-09
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200107.tif
# ***** Completed processing date 2020-01-07 *****
# Processing date: 2020-01-08
# Next date for processing: 2020-01-09
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.168336 to query GFW API for Report.
# Elapsed time: 0:00:00.082627 to create dataframe.
# Elapsed time: 0:00:06.168336 to query GFW API for Report.
# Elapsed time: 0:00:00.082627 to create dataframe.
# Elapsed time: 0:00:02.350919 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.350919 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.333528 to create feature class.
# Completed processing date 2020-01-08 API to Feature Class.
# Elapsed time: 0:00:02.333528 to create feature class.
# Completed processing date 2020-01-08 API to Feature Class.
# Elapsed time: 0:00:07.525597 to create raster from points.
# Completed processing date 2020-01-08 Point to Raster.
# Elapsed time: 0:00:07.525597 to create raster from points.
# Completed processing date 2020-01-08 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200108.tif
# ***** Completed processing date 2020-01-08 *****
# Processing date: 2020-01-09
# Next date for processing: 2020-01-10
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200108.tif
# ***** Completed processing date 2020-01-08 *****
# Processing date: 2020-01-09
# Next date for processing: 2020-01-10
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.999382 to query GFW API for Report.
# Elapsed time: 0:00:00.075520 to create dataframe.
# Elapsed time: 0:00:03.999382 to query GFW API for Report.
# Elapsed time: 0:00:00.075520 to create dataframe.
# Elapsed time: 0:00:02.278510 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.278510 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.294792 to create feature class.
# Completed processing date 2020-01-09 API to Feature Class.
# Elapsed time: 0:00:02.294792 to create feature class.
# Completed processing date 2020-01-09 API to Feature Class.
# Elapsed time: 0:00:06.444667 to create raster from points.
# Completed processing date 2020-01-09 Point to Raster.
# Elapsed time: 0:00:06.444667 to create raster from points.
# Completed processing date 2020-01-09 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200109.tif
# ***** Completed processing date 2020-01-09 *****
# Processing date: 2020-01-10
# Next date for processing: 2020-01-11
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200109.tif
# ***** Completed processing date 2020-01-09 *****
# Processing date: 2020-01-10
# Next date for processing: 2020-01-11
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.808059 to query GFW API for Report.
# Elapsed time: 0:00:00.084519 to create dataframe.
# Elapsed time: 0:00:01.808059 to query GFW API for Report.
# Elapsed time: 0:00:00.084519 to create dataframe.
# Elapsed time: 0:00:02.483593 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.483593 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.361161 to create feature class.
# Completed processing date 2020-01-10 API to Feature Class.
# Elapsed time: 0:00:02.361161 to create feature class.
# Completed processing date 2020-01-10 API to Feature Class.
# Elapsed time: 0:00:07.074144 to create raster from points.
# Completed processing date 2020-01-10 Point to Raster.
# Elapsed time: 0:00:07.074144 to create raster from points.
# Completed processing date 2020-01-10 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200110.tif
# ***** Completed processing date 2020-01-10 *****
# Processing date: 2020-01-11
# Next date for processing: 2020-01-12
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200110.tif
# ***** Completed processing date 2020-01-10 *****
# Processing date: 2020-01-11
# Next date for processing: 2020-01-12
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.931228 to query GFW API for Report.
# Elapsed time: 0:00:00.079007 to create dataframe.
# Elapsed time: 0:00:01.931228 to query GFW API for Report.
# Elapsed time: 0:00:00.079007 to create dataframe.
# Elapsed time: 0:00:02.350350 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.350350 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.290818 to create feature class.
# Completed processing date 2020-01-11 API to Feature Class.
# Elapsed time: 0:00:02.290818 to create feature class.
# Completed processing date 2020-01-11 API to Feature Class.
# Elapsed time: 0:00:06.941413 to create raster from points.
# Completed processing date 2020-01-11 Point to Raster.
# Elapsed time: 0:00:06.941413 to create raster from points.
# Completed processing date 2020-01-11 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200111.tif
# ***** Completed processing date 2020-01-11 *****
# Processing date: 2020-01-12
# Next date for processing: 2020-01-13
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200111.tif
# ***** Completed processing date 2020-01-11 *****
# Processing date: 2020-01-12
# Next date for processing: 2020-01-13
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:09.117311 to query GFW API for Report.
# Elapsed time: 0:00:00.084523 to create dataframe.
# Elapsed time: 0:00:09.117311 to query GFW API for Report.
# Elapsed time: 0:00:00.084523 to create dataframe.
# Elapsed time: 0:00:02.503921 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.503921 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.362151 to create feature class.
# Completed processing date 2020-01-12 API to Feature Class.
# Elapsed time: 0:00:02.362151 to create feature class.
# Completed processing date 2020-01-12 API to Feature Class.
# Elapsed time: 0:00:07.142564 to create raster from points.
# Completed processing date 2020-01-12 Point to Raster.
# Elapsed time: 0:00:07.142564 to create raster from points.
# Completed processing date 2020-01-12 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200112.tif
# ***** Completed processing date 2020-01-12 *****
# Processing date: 2020-01-13
# Next date for processing: 2020-01-14
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200112.tif
# ***** Completed processing date 2020-01-12 *****
# Processing date: 2020-01-13
# Next date for processing: 2020-01-14
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.766400 to query GFW API for Report.
# Elapsed time: 0:00:00.105523 to create dataframe.
# Elapsed time: 0:00:01.766400 to query GFW API for Report.
# Elapsed time: 0:00:00.105523 to create dataframe.
# Elapsed time: 0:00:03.164268 to create spatially enabled dataframe.
# Elapsed time: 0:00:03.164268 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.655262 to create feature class.
# Completed processing date 2020-01-13 API to Feature Class.
# Elapsed time: 0:00:02.655262 to create feature class.
# Completed processing date 2020-01-13 API to Feature Class.
# Elapsed time: 0:00:07.349053 to create raster from points.
# Completed processing date 2020-01-13 Point to Raster.
# Elapsed time: 0:00:07.349053 to create raster from points.
# Completed processing date 2020-01-13 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200113.tif
# ***** Completed processing date 2020-01-13 *****
# Processing date: 2020-01-14
# Next date for processing: 2020-01-15
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200113.tif
# ***** Completed processing date 2020-01-13 *****
# Processing date: 2020-01-14
# Next date for processing: 2020-01-15
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:15.625439 to query GFW API for Report.
# Elapsed time: 0:00:00.087596 to create dataframe.
# Elapsed time: 0:00:15.625439 to query GFW API for Report.
# Elapsed time: 0:00:00.087596 to create dataframe.
# Elapsed time: 0:00:02.656039 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.656039 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.460900 to create feature class.
# Completed processing date 2020-01-14 API to Feature Class.
# Elapsed time: 0:00:02.460900 to create feature class.
# Completed processing date 2020-01-14 API to Feature Class.
# Elapsed time: 0:00:07.233731 to create raster from points.
# Completed processing date 2020-01-14 Point to Raster.
# Elapsed time: 0:00:07.233731 to create raster from points.
# Completed processing date 2020-01-14 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200114.tif
# ***** Completed processing date 2020-01-14 *****
# Processing date: 2020-01-15
# Next date for processing: 2020-01-16
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200114.tif
# ***** Completed processing date 2020-01-14 *****
# Processing date: 2020-01-15
# Next date for processing: 2020-01-16
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.366402 to query GFW API for Report.
# Elapsed time: 0:00:00.065007 to create dataframe.
# Elapsed time: 0:00:03.366402 to query GFW API for Report.
# Elapsed time: 0:00:00.065007 to create dataframe.
# Elapsed time: 0:00:01.978223 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.978223 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.150151 to create feature class.
# Completed processing date 2020-01-15 API to Feature Class.
# Elapsed time: 0:00:02.150151 to create feature class.
# Completed processing date 2020-01-15 API to Feature Class.
# Elapsed time: 0:00:06.973659 to create raster from points.
# Completed processing date 2020-01-15 Point to Raster.
# Elapsed time: 0:00:06.973659 to create raster from points.
# Completed processing date 2020-01-15 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200115.tif
# ***** Completed processing date 2020-01-15 *****
# Processing date: 2020-01-16
# Next date for processing: 2020-01-17
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200115.tif
# ***** Completed processing date 2020-01-15 *****
# Processing date: 2020-01-16
# Next date for processing: 2020-01-17
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.443385 to query GFW API for Report.
# Elapsed time: 0:00:00.073587 to create dataframe.
# Elapsed time: 0:00:01.443385 to query GFW API for Report.
# Elapsed time: 0:00:00.073587 to create dataframe.
# Elapsed time: 0:00:02.203154 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.203154 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.224132 to create feature class.
# Completed processing date 2020-01-16 API to Feature Class.
# Elapsed time: 0:00:02.224132 to create feature class.
# Completed processing date 2020-01-16 API to Feature Class.
# Elapsed time: 0:00:07.049577 to create raster from points.
# Completed processing date 2020-01-16 Point to Raster.
# Elapsed time: 0:00:07.049577 to create raster from points.
# Completed processing date 2020-01-16 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200116.tif
# ***** Completed processing date 2020-01-16 *****
# Processing date: 2020-01-17
# Next date for processing: 2020-01-18
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200116.tif
# ***** Completed processing date 2020-01-16 *****
# Processing date: 2020-01-17
# Next date for processing: 2020-01-18
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.382090 to query GFW API for Report.
# Elapsed time: 0:00:00.079520 to create dataframe.
# Elapsed time: 0:00:03.382090 to query GFW API for Report.
# Elapsed time: 0:00:00.079520 to create dataframe.
# Elapsed time: 0:00:02.356780 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.356780 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.349159 to create feature class.
# Completed processing date 2020-01-17 API to Feature Class.
# Elapsed time: 0:00:02.349159 to create feature class.
# Completed processing date 2020-01-17 API to Feature Class.
# Elapsed time: 0:00:07.070659 to create raster from points.
# Completed processing date 2020-01-17 Point to Raster.
# Elapsed time: 0:00:07.070659 to create raster from points.
# Completed processing date 2020-01-17 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200117.tif
# ***** Completed processing date 2020-01-17 *****
# Processing date: 2020-01-18
# Next date for processing: 2020-01-19
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200117.tif
# ***** Completed processing date 2020-01-17 *****
# Processing date: 2020-01-18
# Next date for processing: 2020-01-19
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.481588 to query GFW API for Report.
# Elapsed time: 0:00:00.077589 to create dataframe.
# Elapsed time: 0:00:03.481588 to query GFW API for Report.
# Elapsed time: 0:00:00.077589 to create dataframe.
# Elapsed time: 0:00:02.296131 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.296131 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.286570 to create feature class.
# Completed processing date 2020-01-18 API to Feature Class.
# Elapsed time: 0:00:02.286570 to create feature class.
# Completed processing date 2020-01-18 API to Feature Class.
# Elapsed time: 0:00:07.025769 to create raster from points.
# Completed processing date 2020-01-18 Point to Raster.
# Elapsed time: 0:00:07.025769 to create raster from points.
# Completed processing date 2020-01-18 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200118.tif
# ***** Completed processing date 2020-01-18 *****
# Processing date: 2020-01-19
# Next date for processing: 2020-01-20
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200118.tif
# ***** Completed processing date 2020-01-18 *****
# Processing date: 2020-01-19
# Next date for processing: 2020-01-20
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:07.717999 to query GFW API for Report.
# Elapsed time: 0:00:00.096590 to create dataframe.
# Elapsed time: 0:00:07.717999 to query GFW API for Report.
# Elapsed time: 0:00:00.096590 to create dataframe.
# Elapsed time: 0:00:02.938604 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.938604 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.556845 to create feature class.
# Completed processing date 2020-01-19 API to Feature Class.
# Elapsed time: 0:00:02.556845 to create feature class.
# Completed processing date 2020-01-19 API to Feature Class.
# Elapsed time: 0:00:06.886461 to create raster from points.
# Completed processing date 2020-01-19 Point to Raster.
# Elapsed time: 0:00:06.886461 to create raster from points.
# Completed processing date 2020-01-19 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200119.tif
# ***** Completed processing date 2020-01-19 *****
# Processing date: 2020-01-20
# Next date for processing: 2020-01-21
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200119.tif
# ***** Completed processing date 2020-01-19 *****
# Processing date: 2020-01-20
# Next date for processing: 2020-01-21
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.236006 to query GFW API for Report.
# Elapsed time: 0:00:00.069520 to create dataframe.
# Elapsed time: 0:00:03.236006 to query GFW API for Report.
# Elapsed time: 0:00:00.069520 to create dataframe.
# Elapsed time: 0:00:02.080553 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.080553 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.235635 to create feature class.
# Completed processing date 2020-01-20 API to Feature Class.
# Elapsed time: 0:00:02.235635 to create feature class.
# Completed processing date 2020-01-20 API to Feature Class.
# Elapsed time: 0:00:07.220288 to create raster from points.
# Completed processing date 2020-01-20 Point to Raster.
# Elapsed time: 0:00:07.220288 to create raster from points.
# Completed processing date 2020-01-20 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200120.tif
# ***** Completed processing date 2020-01-20 *****
# Processing date: 2020-01-21
# Next date for processing: 2020-01-22
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200120.tif
# ***** Completed processing date 2020-01-20 *****
# Processing date: 2020-01-21
# Next date for processing: 2020-01-22
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.616989 to query GFW API for Report.
# Elapsed time: 0:00:00.070517 to create dataframe.
# Elapsed time: 0:00:01.616989 to query GFW API for Report.
# Elapsed time: 0:00:00.070517 to create dataframe.
# Elapsed time: 0:00:02.049235 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.049235 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.188620 to create feature class.
# Completed processing date 2020-01-21 API to Feature Class.
# Elapsed time: 0:00:02.188620 to create feature class.
# Completed processing date 2020-01-21 API to Feature Class.
# Elapsed time: 0:00:06.940505 to create raster from points.
# Completed processing date 2020-01-21 Point to Raster.
# Elapsed time: 0:00:06.940505 to create raster from points.
# Completed processing date 2020-01-21 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200121.tif
# ***** Completed processing date 2020-01-21 *****
# Processing date: 2020-01-22
# Next date for processing: 2020-01-23
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200121.tif
# ***** Completed processing date 2020-01-21 *****
# Processing date: 2020-01-22
# Next date for processing: 2020-01-23
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.726041 to query GFW API for Report.
# Elapsed time: 0:00:00.086523 to create dataframe.
# Elapsed time: 0:00:03.726041 to query GFW API for Report.
# Elapsed time: 0:00:00.086523 to create dataframe.
# Elapsed time: 0:00:02.563682 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.563682 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.392110 to create feature class.
# Completed processing date 2020-01-22 API to Feature Class.
# Elapsed time: 0:00:02.392110 to create feature class.
# Completed processing date 2020-01-22 API to Feature Class.
# Elapsed time: 0:00:07.214678 to create raster from points.
# Completed processing date 2020-01-22 Point to Raster.
# Elapsed time: 0:00:07.214678 to create raster from points.
# Completed processing date 2020-01-22 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200122.tif
# ***** Completed processing date 2020-01-22 *****
# Processing date: 2020-01-23
# Next date for processing: 2020-01-24
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200122.tif
# ***** Completed processing date 2020-01-22 *****
# Processing date: 2020-01-23
# Next date for processing: 2020-01-24
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.594719 to query GFW API for Report.
# Elapsed time: 0:00:00.084446 to create dataframe.
# Elapsed time: 0:00:01.594719 to query GFW API for Report.
# Elapsed time: 0:00:00.084446 to create dataframe.
# Elapsed time: 0:00:02.519587 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.519587 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.353951 to create feature class.
# Completed processing date 2020-01-23 API to Feature Class.
# Elapsed time: 0:00:02.353951 to create feature class.
# Completed processing date 2020-01-23 API to Feature Class.
# Elapsed time: 0:00:06.851274 to create raster from points.
# Completed processing date 2020-01-23 Point to Raster.
# Elapsed time: 0:00:06.851274 to create raster from points.
# Completed processing date 2020-01-23 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200123.tif
# ***** Completed processing date 2020-01-23 *****
# Processing date: 2020-01-24
# Next date for processing: 2020-01-25
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200123.tif
# ***** Completed processing date 2020-01-23 *****
# Processing date: 2020-01-24
# Next date for processing: 2020-01-25
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:02.210747 to query GFW API for Report.
# Elapsed time: 0:00:00.075517 to create dataframe.
# Elapsed time: 0:00:02.210747 to query GFW API for Report.
# Elapsed time: 0:00:00.075517 to create dataframe.
# Elapsed time: 0:00:02.252098 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.252098 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.279276 to create feature class.
# Completed processing date 2020-01-24 API to Feature Class.
# Elapsed time: 0:00:02.279276 to create feature class.
# Completed processing date 2020-01-24 API to Feature Class.
# Elapsed time: 0:00:07.521067 to create raster from points.
# Completed processing date 2020-01-24 Point to Raster.
# Elapsed time: 0:00:07.521067 to create raster from points.
# Completed processing date 2020-01-24 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200124.tif
# ***** Completed processing date 2020-01-24 *****
# Processing date: 2020-01-25
# Next date for processing: 2020-01-26
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200124.tif
# ***** Completed processing date 2020-01-24 *****
# Processing date: 2020-01-25
# Next date for processing: 2020-01-26
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:02.994299 to query GFW API for Report.
# Elapsed time: 0:00:00.066799 to create dataframe.
# Elapsed time: 0:00:02.994299 to query GFW API for Report.
# Elapsed time: 0:00:00.066799 to create dataframe.
# Elapsed time: 0:00:01.970704 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.970704 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.152074 to create feature class.
# Completed processing date 2020-01-25 API to Feature Class.
# Elapsed time: 0:00:02.152074 to create feature class.
# Completed processing date 2020-01-25 API to Feature Class.
# Elapsed time: 0:00:07.053383 to create raster from points.
# Completed processing date 2020-01-25 Point to Raster.
# Elapsed time: 0:00:07.053383 to create raster from points.
# Completed processing date 2020-01-25 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200125.tif
# ***** Completed processing date 2020-01-25 *****
# Processing date: 2020-01-26
# Next date for processing: 2020-01-27
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200125.tif
# ***** Completed processing date 2020-01-25 *****
# Processing date: 2020-01-26
# Next date for processing: 2020-01-27
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:02.235707 to query GFW API for Report.
# Elapsed time: 0:00:00.087517 to create dataframe.
# Elapsed time: 0:00:02.235707 to query GFW API for Report.
# Elapsed time: 0:00:00.087517 to create dataframe.
# Elapsed time: 0:00:02.501053 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.501053 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.366894 to create feature class.
# Completed processing date 2020-01-26 API to Feature Class.
# Elapsed time: 0:00:02.366894 to create feature class.
# Completed processing date 2020-01-26 API to Feature Class.
# Elapsed time: 0:00:07.472807 to create raster from points.
# Completed processing date 2020-01-26 Point to Raster.
# Elapsed time: 0:00:07.472807 to create raster from points.
# Completed processing date 2020-01-26 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200126.tif
# ***** Completed processing date 2020-01-26 *****
# Processing date: 2020-01-27
# Next date for processing: 2020-01-28
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200126.tif
# ***** Completed processing date 2020-01-26 *****
# Processing date: 2020-01-27
# Next date for processing: 2020-01-28
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:02.138303 to query GFW API for Report.
# Elapsed time: 0:00:00.072107 to create dataframe.
# Elapsed time: 0:00:02.138303 to query GFW API for Report.
# Elapsed time: 0:00:00.072107 to create dataframe.
# Elapsed time: 0:00:02.103250 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.103250 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.206866 to create feature class.
# Completed processing date 2020-01-27 API to Feature Class.
# Elapsed time: 0:00:02.206866 to create feature class.
# Completed processing date 2020-01-27 API to Feature Class.
# Elapsed time: 0:00:07.269378 to create raster from points.
# Completed processing date 2020-01-27 Point to Raster.
# Elapsed time: 0:00:07.269378 to create raster from points.
# Completed processing date 2020-01-27 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200127.tif
# ***** Completed processing date 2020-01-27 *****
# Processing date: 2020-01-28
# Next date for processing: 2020-01-29
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200127.tif
# ***** Completed processing date 2020-01-27 *****
# Processing date: 2020-01-28
# Next date for processing: 2020-01-29
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.871752 to query GFW API for Report.
# Elapsed time: 0:00:00.074506 to create dataframe.
# Elapsed time: 0:00:04.871752 to query GFW API for Report.
# Elapsed time: 0:00:00.074506 to create dataframe.
# Elapsed time: 0:00:02.275928 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.275928 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.262427 to create feature class.
# Completed processing date 2020-01-28 API to Feature Class.
# Elapsed time: 0:00:02.262427 to create feature class.
# Completed processing date 2020-01-28 API to Feature Class.
# Elapsed time: 0:00:07.221184 to create raster from points.
# Completed processing date 2020-01-28 Point to Raster.
# Elapsed time: 0:00:07.221184 to create raster from points.
# Completed processing date 2020-01-28 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200128.tif
# ***** Completed processing date 2020-01-28 *****
# Processing date: 2020-01-29
# Next date for processing: 2020-01-30
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200128.tif
# ***** Completed processing date 2020-01-28 *****
# Processing date: 2020-01-29
# Next date for processing: 2020-01-30
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.496125 to query GFW API for Report.
# Elapsed time: 0:00:00.073000 to create dataframe.
# Elapsed time: 0:00:01.496125 to query GFW API for Report.
# Elapsed time: 0:00:00.073000 to create dataframe.
# Elapsed time: 0:00:02.211738 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.211738 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.275434 to create feature class.
# Completed processing date 2020-01-29 API to Feature Class.
# Elapsed time: 0:00:02.275434 to create feature class.
# Completed processing date 2020-01-29 API to Feature Class.
# Elapsed time: 0:00:07.092833 to create raster from points.
# Completed processing date 2020-01-29 Point to Raster.
# Elapsed time: 0:00:07.092833 to create raster from points.
# Completed processing date 2020-01-29 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200129.tif
# ***** Completed processing date 2020-01-29 *****
# Processing date: 2020-01-30
# Next date for processing: 2020-01-31
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200129.tif
# ***** Completed processing date 2020-01-29 *****
# Processing date: 2020-01-30
# Next date for processing: 2020-01-31
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.587478 to query GFW API for Report.
# Elapsed time: 0:00:00.068522 to create dataframe.
# Elapsed time: 0:00:01.587478 to query GFW API for Report.
# Elapsed time: 0:00:00.068522 to create dataframe.
# Elapsed time: 0:00:01.980137 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.980137 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.176473 to create feature class.
# Completed processing date 2020-01-30 API to Feature Class.
# Elapsed time: 0:00:02.176473 to create feature class.
# Completed processing date 2020-01-30 API to Feature Class.
# Elapsed time: 0:00:06.745359 to create raster from points.
# Completed processing date 2020-01-30 Point to Raster.
# Elapsed time: 0:00:06.745359 to create raster from points.
# Completed processing date 2020-01-30 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200130.tif
# ***** Completed processing date 2020-01-30 *****
# Processing date: 2020-01-31
# Next date for processing: 2020-02-01
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200130.tif
# ***** Completed processing date 2020-01-30 *****
# Processing date: 2020-01-31
# Next date for processing: 2020-02-01
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.430020 to query GFW API for Report.
# Elapsed time: 0:00:00.090585 to create dataframe.
# Elapsed time: 0:00:01.430020 to query GFW API for Report.
# Elapsed time: 0:00:00.090585 to create dataframe.
# Elapsed time: 0:00:02.681787 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.681787 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.443663 to create feature class.
# Completed processing date 2020-01-31 API to Feature Class.
# Elapsed time: 0:00:02.443663 to create feature class.
# Completed processing date 2020-01-31 API to Feature Class.
# Elapsed time: 0:00:06.954792 to create raster from points.
# Completed processing date 2020-01-31 Point to Raster.
# Elapsed time: 0:00:06.954792 to create raster from points.
# Completed processing date 2020-01-31 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200131.tif
# ***** Completed processing date 2020-01-31 *****
# Processing date: 2020-02-01
# Next date for processing: 2020-02-02
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200131.tif
# ***** Completed processing date 2020-01-31 *****
# Processing date: 2020-02-01
# Next date for processing: 2020-02-02
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.875448 to query GFW API for Report.
# Elapsed time: 0:00:00.073517 to create dataframe.
# Elapsed time: 0:00:01.875448 to query GFW API for Report.
# Elapsed time: 0:00:00.073517 to create dataframe.
# Elapsed time: 0:00:02.193751 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.193751 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.227411 to create feature class.
# Completed processing date 2020-02-01 API to Feature Class.
# Elapsed time: 0:00:02.227411 to create feature class.
# Completed processing date 2020-02-01 API to Feature Class.
# Elapsed time: 0:00:07.344737 to create raster from points.
# Completed processing date 2020-02-01 Point to Raster.
# Elapsed time: 0:00:07.344737 to create raster from points.
# Completed processing date 2020-02-01 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200201.tif
# ***** Completed processing date 2020-02-01 *****
# Processing date: 2020-02-02
# Next date for processing: 2020-02-03
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200201.tif
# ***** Completed processing date 2020-02-01 *****
# Processing date: 2020-02-02
# Next date for processing: 2020-02-03
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.160058 to query GFW API for Report.
# Elapsed time: 0:00:00.067515 to create dataframe.
# Elapsed time: 0:00:04.160058 to query GFW API for Report.
# Elapsed time: 0:00:00.067515 to create dataframe.
# Elapsed time: 0:00:01.975056 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.975056 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.181028 to create feature class.
# Completed processing date 2020-02-02 API to Feature Class.
# Elapsed time: 0:00:02.181028 to create feature class.
# Completed processing date 2020-02-02 API to Feature Class.
# Elapsed time: 0:00:06.903820 to create raster from points.
# Completed processing date 2020-02-02 Point to Raster.
# Elapsed time: 0:00:06.903820 to create raster from points.
# Completed processing date 2020-02-02 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200202.tif
# ***** Completed processing date 2020-02-02 *****
# Processing date: 2020-02-03
# Next date for processing: 2020-02-04
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200202.tif
# ***** Completed processing date 2020-02-02 *****
# Processing date: 2020-02-03
# Next date for processing: 2020-02-04
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.628590 to query GFW API for Report.
# Elapsed time: 0:00:00.073519 to create dataframe.
# Elapsed time: 0:00:01.628590 to query GFW API for Report.
# Elapsed time: 0:00:00.073519 to create dataframe.
# Elapsed time: 0:00:02.206668 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.206668 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.259827 to create feature class.
# Completed processing date 2020-02-03 API to Feature Class.
# Elapsed time: 0:00:02.259827 to create feature class.
# Completed processing date 2020-02-03 API to Feature Class.
# Elapsed time: 0:00:07.223018 to create raster from points.
# Completed processing date 2020-02-03 Point to Raster.
# Elapsed time: 0:00:07.223018 to create raster from points.
# Completed processing date 2020-02-03 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200203.tif
# ***** Completed processing date 2020-02-03 *****
# Processing date: 2020-02-04
# Next date for processing: 2020-02-05
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200203.tif
# ***** Completed processing date 2020-02-03 *****
# Processing date: 2020-02-04
# Next date for processing: 2020-02-05
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.507358 to query GFW API for Report.
# Elapsed time: 0:00:00.083590 to create dataframe.
# Elapsed time: 0:00:03.507358 to query GFW API for Report.
# Elapsed time: 0:00:00.083590 to create dataframe.
# Elapsed time: 0:00:02.458690 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.458690 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.340513 to create feature class.
# Completed processing date 2020-02-04 API to Feature Class.
# Elapsed time: 0:00:02.340513 to create feature class.
# Completed processing date 2020-02-04 API to Feature Class.
# Elapsed time: 0:00:06.806220 to create raster from points.
# Completed processing date 2020-02-04 Point to Raster.
# Elapsed time: 0:00:06.806220 to create raster from points.
# Completed processing date 2020-02-04 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200204.tif
# ***** Completed processing date 2020-02-04 *****
# Processing date: 2020-02-05
# Next date for processing: 2020-02-06
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20200204.tif
# ***** Completed processing date 2020-02-04 *****
# Processing date: 2020-02-05
# ...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250919.tif
# ***** Completed processing date 2025-09-19 *****
# Processing date: 2025-09-20
# Next date for processing: 2025-09-21
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.715223 to query GFW API for Report.
# Elapsed time: 0:00:00.081522 to create dataframe.
# Elapsed time: 0:00:01.715223 to query GFW API for Report.
# Elapsed time: 0:00:00.081522 to create dataframe.
# Elapsed time: 0:00:02.366244 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.366244 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.403388 to create feature class.
# Completed processing date 2025-09-20 API to Feature Class.
# Elapsed time: 0:00:02.403388 to create feature class.
# Completed processing date 2025-09-20 API to Feature Class.
# Elapsed time: 0:00:07.371319 to create raster from points.
# Completed processing date 2025-09-20 Point to Raster.
# Elapsed time: 0:00:07.371319 to create raster from points.
# Completed processing date 2025-09-20 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250920.tif
# ***** Completed processing date 2025-09-20 *****
# Processing date: 2025-09-21
# Next date for processing: 2025-09-22
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250920.tif
# ***** Completed processing date 2025-09-20 *****
# Processing date: 2025-09-21
# Next date for processing: 2025-09-22
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.002204 to query GFW API for Report.
# Elapsed time: 0:00:00.046476 to create dataframe.
# Elapsed time: 0:00:06.002204 to query GFW API for Report.
# Elapsed time: 0:00:00.046476 to create dataframe.
# Elapsed time: 0:00:01.340955 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.340955 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.071839 to create feature class.
# Completed processing date 2025-09-21 API to Feature Class.
# Elapsed time: 0:00:02.071839 to create feature class.
# Completed processing date 2025-09-21 API to Feature Class.
# Elapsed time: 0:00:07.923435 to create raster from points.
# Completed processing date 2025-09-21 Point to Raster.
# Elapsed time: 0:00:07.923435 to create raster from points.
# Completed processing date 2025-09-21 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250921.tif
# ***** Completed processing date 2025-09-21 *****
# Processing date: 2025-09-22
# Next date for processing: 2025-09-23
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250921.tif
# ***** Completed processing date 2025-09-21 *****
# Processing date: 2025-09-22
# Next date for processing: 2025-09-23
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.938349 to query GFW API for Report.
# Elapsed time: 0:00:00.057334 to create dataframe.
# Elapsed time: 0:00:01.938349 to query GFW API for Report.
# Elapsed time: 0:00:00.057334 to create dataframe.
# Elapsed time: 0:00:01.662352 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.662352 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.189595 to create feature class.
# Completed processing date 2025-09-22 API to Feature Class.
# Elapsed time: 0:00:02.189595 to create feature class.
# Completed processing date 2025-09-22 API to Feature Class.
# Elapsed time: 0:00:07.917371 to create raster from points.
# Completed processing date 2025-09-22 Point to Raster.
# Elapsed time: 0:00:07.917371 to create raster from points.
# Completed processing date 2025-09-22 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250922.tif
# ***** Completed processing date 2025-09-22 *****
# Processing date: 2025-09-23
# Next date for processing: 2025-09-24
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250922.tif
# ***** Completed processing date 2025-09-22 *****
# Processing date: 2025-09-23
# Next date for processing: 2025-09-24
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.452679 to query GFW API for Report.
# Elapsed time: 0:00:00.056519 to create dataframe.
# Elapsed time: 0:00:01.452679 to query GFW API for Report.
# Elapsed time: 0:00:00.056519 to create dataframe.
# Elapsed time: 0:00:01.528520 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.528520 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.146904 to create feature class.
# Completed processing date 2025-09-23 API to Feature Class.
# Elapsed time: 0:00:02.146904 to create feature class.
# Completed processing date 2025-09-23 API to Feature Class.
# Elapsed time: 0:00:07.417958 to create raster from points.
# Completed processing date 2025-09-23 Point to Raster.
# Elapsed time: 0:00:07.417958 to create raster from points.
# Completed processing date 2025-09-23 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250923.tif
# ***** Completed processing date 2025-09-23 *****
# Processing date: 2025-09-24
# Next date for processing: 2025-09-25
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250923.tif
# ***** Completed processing date 2025-09-23 *****
# Processing date: 2025-09-24
# Next date for processing: 2025-09-25
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:02.973468 to query GFW API for Report.
# Elapsed time: 0:00:00.045591 to create dataframe.
# Elapsed time: 0:00:02.973468 to query GFW API for Report.
# Elapsed time: 0:00:00.045591 to create dataframe.
# Elapsed time: 0:00:01.300200 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.300200 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.036055 to create feature class.
# Completed processing date 2025-09-24 API to Feature Class.
# Elapsed time: 0:00:02.036055 to create feature class.
# Completed processing date 2025-09-24 API to Feature Class.
# Elapsed time: 0:00:07.571857 to create raster from points.
# Completed processing date 2025-09-24 Point to Raster.
# Elapsed time: 0:00:07.571857 to create raster from points.
# Completed processing date 2025-09-24 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250924.tif
# ***** Completed processing date 2025-09-24 *****
# Processing date: 2025-09-25
# Next date for processing: 2025-09-26
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250924.tif
# ***** Completed processing date 2025-09-24 *****
# Processing date: 2025-09-25
# Next date for processing: 2025-09-26
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:06.236825 to query GFW API for Report.
# Elapsed time: 0:00:00.134372 to create dataframe.
# Elapsed time: 0:00:06.236825 to query GFW API for Report.
# Elapsed time: 0:00:00.134372 to create dataframe.
# Elapsed time: 0:00:03.822396 to create spatially enabled dataframe.
# Elapsed time: 0:00:03.822396 to create spatially enabled dataframe.
# Elapsed time: 0:00:03.085168 to create feature class.
# Completed processing date 2025-09-25 API to Feature Class.
# Elapsed time: 0:00:03.085168 to create feature class.
# Completed processing date 2025-09-25 API to Feature Class.
# Elapsed time: 0:00:07.537683 to create raster from points.
# Completed processing date 2025-09-25 Point to Raster.
# Elapsed time: 0:00:07.537683 to create raster from points.
# Completed processing date 2025-09-25 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250925.tif
# ***** Completed processing date 2025-09-25 *****
# Processing date: 2025-09-26
# Next date for processing: 2025-09-27
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250925.tif
# ***** Completed processing date 2025-09-25 *****
# Processing date: 2025-09-26
# Next date for processing: 2025-09-27
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.529276 to query GFW API for Report.
# Elapsed time: 0:00:00.054999 to create dataframe.
# Elapsed time: 0:00:01.529276 to query GFW API for Report.
# Elapsed time: 0:00:00.054999 to create dataframe.
# Elapsed time: 0:00:01.500314 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.500314 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.117504 to create feature class.
# Completed processing date 2025-09-26 API to Feature Class.
# Elapsed time: 0:00:02.117504 to create feature class.
# Completed processing date 2025-09-26 API to Feature Class.
# Elapsed time: 0:00:07.400469 to create raster from points.
# Completed processing date 2025-09-26 Point to Raster.
# Elapsed time: 0:00:07.400469 to create raster from points.
# Completed processing date 2025-09-26 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250926.tif
# ***** Completed processing date 2025-09-26 *****
# Processing date: 2025-09-27
# Next date for processing: 2025-09-28
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250926.tif
# ***** Completed processing date 2025-09-26 *****
# Processing date: 2025-09-27
# Next date for processing: 2025-09-28
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:05.289290 to query GFW API for Report.
# Elapsed time: 0:00:00.070515 to create dataframe.
# Elapsed time: 0:00:05.289290 to query GFW API for Report.
# Elapsed time: 0:00:00.070515 to create dataframe.
# Elapsed time: 0:00:02.029519 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.029519 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.304261 to create feature class.
# Completed processing date 2025-09-27 API to Feature Class.
# Elapsed time: 0:00:02.304261 to create feature class.
# Completed processing date 2025-09-27 API to Feature Class.
# Elapsed time: 0:00:07.468174 to create raster from points.
# Completed processing date 2025-09-27 Point to Raster.
# Elapsed time: 0:00:07.468174 to create raster from points.
# Completed processing date 2025-09-27 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250927.tif
# ***** Completed processing date 2025-09-27 *****
# Processing date: 2025-09-28
# Next date for processing: 2025-09-29
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250927.tif
# ***** Completed processing date 2025-09-27 *****
# Processing date: 2025-09-28
# Next date for processing: 2025-09-29
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:01.846418 to query GFW API for Report.
# Elapsed time: 0:00:00.063955 to create dataframe.
# Elapsed time: 0:00:01.846418 to query GFW API for Report.
# Elapsed time: 0:00:00.063955 to create dataframe.
# Elapsed time: 0:00:01.807765 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.807765 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.194956 to create feature class.
# Completed processing date 2025-09-28 API to Feature Class.
# Elapsed time: 0:00:02.194956 to create feature class.
# Completed processing date 2025-09-28 API to Feature Class.
# Elapsed time: 0:00:08.389810 to create raster from points.
# Completed processing date 2025-09-28 Point to Raster.
# Elapsed time: 0:00:08.389810 to create raster from points.
# Completed processing date 2025-09-28 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250928.tif
# ***** Completed processing date 2025-09-28 *****
# Processing date: 2025-09-29
# Next date for processing: 2025-09-30
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250928.tif
# ***** Completed processing date 2025-09-28 *****
# Processing date: 2025-09-29
# Next date for processing: 2025-09-30
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.734525 to query GFW API for Report.
# Elapsed time: 0:00:00.058590 to create dataframe.
# Elapsed time: 0:00:03.734525 to query GFW API for Report.
# Elapsed time: 0:00:00.058590 to create dataframe.
# Elapsed time: 0:00:01.738233 to create spatially enabled dataframe.
# Elapsed time: 0:00:01.738233 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.197159 to create feature class.
# Completed processing date 2025-09-29 API to Feature Class.
# Elapsed time: 0:00:02.197159 to create feature class.
# Completed processing date 2025-09-29 API to Feature Class.
# Elapsed time: 0:00:07.624573 to create raster from points.
# Completed processing date 2025-09-29 Point to Raster.
# Elapsed time: 0:00:07.624573 to create raster from points.
# Completed processing date 2025-09-29 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250929.tif
# ***** Completed processing date 2025-09-29 *****
# Processing date: 2025-09-30
# Next date for processing: 2025-10-01
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250929.tif
# ***** Completed processing date 2025-09-29 *****
# Processing date: 2025-09-30
# Next date for processing: 2025-10-01
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:04.161788 to query GFW API for Report.
# Elapsed time: 0:00:00.074006 to create dataframe.
# Elapsed time: 0:00:04.161788 to query GFW API for Report.
# Elapsed time: 0:00:00.074006 to create dataframe.
# Elapsed time: 0:00:02.181650 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.181650 to create spatially enabled dataframe.
# Elapsed time: 0:00:02.388509 to create feature class.
# Completed processing date 2025-09-30 API to Feature Class.
# Elapsed time: 0:00:02.388509 to create feature class.
# Completed processing date 2025-09-30 API to Feature Class.
# Elapsed time: 0:00:08.003736 to create raster from points.
# Completed processing date 2025-09-30 Point to Raster.
# Elapsed time: 0:00:08.003736 to create raster from points.
# Completed processing date 2025-09-30 Point to Raster.
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250930.tif
# ***** Completed processing date 2025-09-30 *****
# Processing date: 2025-10-01
# Next date for processing: 2025-10-02
# Waiting 10 seconds to eliminate too many requests error...
# Deleted intermediate raster: C:\temp\gfw\sar_detection_daily_matched\sar_detection_daily_matched_20250930.tif
# ***** Completed processing date 2025-09-30 *****
# Processing date: 2025-10-01
# Next date for processing: 2025-10-02
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.204635 to query GFW API for Report.
# Error processing date 2025-10-01: 'lat'
# Processing date: 2025-10-02
# Next date for processing: 2025-10-03
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:03.204635 to query GFW API for Report.
# Error processing date 2025-10-01: 'lat'
# Processing date: 2025-10-02
# Next date for processing: 2025-10-03
# Waiting 10 seconds to eliminate too many requests error...
# Elapsed time: 0:00:02.049154 to query GFW API for Report.
# Error processing date 2025-10-02: 'lat'
# Elapsed time: 0:00:02.049154 to query GFW API for Report.
# Error processing date 2025-10-02: 'lat'

# %%
tif_files = [f for f in os.listdir(output_raster_workspace) if f.endswith('.tif')]
print(tif_files)
# Out:
# ['sar_detection_daily_matched_20200101_global.tif', 'sar_detection_daily_matched_20200102_global.tif', 'sar_detection_daily_matched_20200103_global.tif', 'sar_detection_daily_matched_20200104_global.tif', 'sar_detection_daily_matched_20200105_global.tif', 'sar_detection_daily_matched_20200106_global.tif', 'sar_detection_daily_matched_20200107_global.tif', 'sar_detection_daily_matched_20200108_global.tif', 'sar_detection_daily_matched_20200109_global.tif', 'sar_detection_daily_matched_20200110_global.tif', 'sar_detection_daily_matched_20200111_global.tif', 'sar_detection_daily_matched_20200112_global.tif', 'sar_detection_daily_matched_20200113_global.tif', 'sar_detection_daily_matched_20200114_global.tif', 'sar_detection_daily_matched_20200115_global.tif', 'sar_detection_daily_matched_20200116_global.tif', 'sar_detection_daily_matched_20200117_global.tif', 'sar_detection_daily_matched_20200118_global.tif', 'sar_detection_daily_matched_20200119_global.tif', 'sar_detection_daily_matched_20200120_global.tif', 'sar_detection_daily_matched_20200121_global.tif', 'sar_detection_daily_matched_20200122_global.tif', 'sar_detection_daily_matched_20200123_global.tif', 'sar_detection_daily_matched_20200124_global.tif', 'sar_detection_daily_matched_20200125_global.tif', 'sar_detection_daily_matched_20200126_global.tif', 'sar_detection_daily_matched_20200127_global.tif', 'sar_detection_daily_matched_20200128_global.tif', 'sar_detection_daily_matched_20200129_global.tif', 'sar_detection_daily_matched_20200130_global.tif', 'sar_detection_daily_matched_20200131_global.tif', 'sar_detection_daily_matched_20200201_global.tif', 'sar_detection_daily_matched_20200202_global.tif', 'sar_detection_daily_matched_20200203_global.tif', 'sar_detection_daily_matched_20200204_global.tif', 'sar_detection_daily_matched_20200205_global.tif', 'sar_detection_daily_matched_20200206_global.tif', 'sar_detection_daily_matched_20200207_global.tif', 'sar_detection_daily_matched_20200208_global.tif', 'sar_detection_daily_matched_20200209_global.tif', 'sar_detection_daily_matched_20200210_global.tif', 'sar_detection_daily_matched_20200211_global.tif', 'sar_detection_daily_matched_20200212_global.tif', 'sar_detection_daily_matched_20200213_global.tif', 'sar_detection_daily_matched_20200214_global.tif', 'sar_detection_daily_matched_20200215_global.tif', 'sar_detection_daily_matched_20200216_global.tif', 'sar_detection_daily_matched_20200217_global.tif', 'sar_detection_daily_matched_20200218_global.tif', 'sar_detection_daily_matched_20200219_global.tif', 'sar_detection_daily_matched_20200220_global.tif', 'sar_detection_daily_matched_20200221_global.tif', 'sar_detection_daily_matched_20200222_global.tif', 'sar_detection_daily_matched_20200223_global.tif', 'sar_detection_daily_matched_20200224_global.tif', 'sar_detection_daily_matched_20200225_global.tif', 'sar_detection_daily_matched_20200226_global.tif', 'sar_detection_daily_matched_20200227_global.tif', 'sar_detection_daily_matched_20200228_global.tif', 'sar_detection_daily_matched_20200229_global.tif', 'sar_detection_daily_matched_20200301_global.tif', 'sar_detection_daily_matched_20200302_global.tif', 'sar_detection_daily_matched_20200303_global.tif', 'sar_detection_daily_matched_20200304_global.tif', 'sar_detection_daily_matched_20200305_global.tif', 'sar_detection_daily_matched_20200306_global.tif', 'sar_detection_daily_matched_20200307_global.tif', 'sar_detection_daily_matched_20200308_global.tif', 'sar_detection_daily_matched_20200309_global.tif', 'sar_detection_daily_matched_20200310_global.tif', 'sar_detection_daily_matched_20200311_global.tif', 'sar_detection_daily_matched_20200312_global.tif', 'sar_detection_daily_matched_20200313_global.tif', 'sar_detection_daily_matched_20200314_global.tif', 'sar_detection_daily_matched_20200315_global.tif', 'sar_detection_daily_matched_20200316_global.tif', 'sar_detection_daily_matched_20200317_global.tif', 'sar_detection_daily_matched_20200318_global.tif', 'sar_detection_daily_ ...

# %%
md_path = f"{workspace}/{gdb_name}/{product_name}"
if not arcpy.Exists(md_path):
    arcpy.CreateMosaicDataset_management(
        in_workspace=f"{workspace}/{gdb_name}",
        in_mosaicdataset_name=product_name,
        coordinate_system=4326
    )
print(f"Mosaic dataset '{product_name}' created in {gdb_name}")
# Out:
# Mosaic dataset 'sar_detection_daily_matched' created in gfw_sar_detection_daily_matched.gdb

# %%
arcpy.management.AddRastersToMosaicDataset(
    in_mosaic_dataset=f"{gdb_name}/{product_name}",
    raster_type="Raster Dataset",
    input_path=output_raster_workspace,
    update_cellsize_ranges="UPDATE_CELL_SIZES",
    update_boundary="UPDATE_BOUNDARY",
    update_overviews="NO_OVERVIEWS",
    maximum_pyramid_levels=None,
    maximum_cell_size=0,
    minimum_dimension=1500,
    spatial_reference=None,
    filter="*.TIF",
    sub_folder="NO_SUBFOLDERS",
    duplicate_items_action="EXCLUDE_DUPLICATES",
    build_pyramids="NO_PYRAMIDS",
    calculate_statistics="NO_STATISTICS",
    build_thumbnails="NO_THUMBNAILS",
    operation_description="",
    force_spatial_reference="NO_FORCE_SPATIAL_REFERENCE",
    estimate_statistics="NO_STATISTICS",
    aux_inputs=None,
    enable_pixel_cache="NO_PIXEL_CACHE",
    cache_location=workspace
)
# Out:
# <Result 'C:\\temp\\gfw\\gfw_sar_detection_daily_matched.gdb\\sar_detection_daily_matched'>

# %%
arcpy.management.CalculateField(
    in_table=f"{gdb_name}/{product_name}",
    field="date_text",
    expression='!Name!.split("_")[4]',
    expression_type="PYTHON3",
    code_block="",
    field_type="TEXT",
    enforce_domains="NO_ENFORCE_DOMAINS"
)
# Out:
# <Result 'C:\\temp\\gfw\\gfw_sar_detection_daily_matched.gdb\\sar_detection_daily_matched'>

# %%
arcpy.management.CalculateField(
    in_table=f"{gdb_name}/{product_name}",
    field="sar_date",
    expression='str(!date_text!)[4:6] + "/" + str(!date_text!)[6:8] + "/" + str(!date_text!)[:4]',
    expression_type="PYTHON3",
    code_block="",
    field_type="DATE",
    enforce_domains="NO_ENFORCE_DOMAINS"
)
# Out:
# <Result 'C:\\temp\\gfw\\gfw_sar_detection_daily_matched.gdb\\sar_detection_daily_matched'>

# %%
arcpy.management.CalculateField(
    in_table=f"{gdb_name}/{product_name}",
    field="variable_mapped",
    expression=f'"{variable_name}"',
    expression_type="PYTHON3",
    code_block="",
    field_type="TEXT",
    enforce_domains="NO_ENFORCE_DOMAINS"
)
# Out:
# <Result 'C:\\temp\\gfw\\gfw_sar_detection_daily_matched.gdb\\sar_detection_daily_matched'>

# %%
arcpy.md.BuildMultidimensionalInfo(
    in_mosaic_dataset=f"{gdb_name}/{product_name}",
    variable_field="variable_mapped",
    dimension_fields="sar_date date days",
    variable_desc_units="'SAR Detections' 'SAR Detections' count",
    delete_multidimensional_info="NO_DELETE_MULTIDIMENSIONAL_INFO"
)
# Out:
# <Result 'C:\\temp\\gfw\\gfw_sar_detection_daily_matched.gdb\\sar_detection_daily_matched'>

# %%
arcpy.management.SetMosaicDatasetProperties(
    in_mosaic_dataset=f"{gdb_name}/{product_name}",
    rows_maximum_imagesize=4100,
    columns_maximum_imagesize=15000,
    allowed_compressions="None;JPEG;LZ77;LERC",
    default_compression_type="None",
    JPEG_quality=75,
    LERC_Tolerance=0.01,
    resampling_type="NEAREST",
    clip_to_footprints="NOT_CLIP",
    footprints_may_contain_nodata="FOOTPRINTS_MAY_CONTAIN_NODATA",
    clip_to_boundary="CLIP",
    color_correction="NOT_APPLY",
    allowed_mensuration_capabilities="Basic",
    default_mensuration_capabilities="Basic",
    allowed_mosaic_methods="ByAttribute;NorthWest;Center;LockRaster;Nadir;Viewpoint;Seamline;None",
    default_mosaic_method="ByAttribute",
    order_field="StdTime",
    order_base="",
    sorting_order="DESCENDING",
    mosaic_operator="FIRST",
    blend_width=10,
    view_point_x=600,
    view_point_y=300,
    max_num_per_mosaic=20,
    cell_size_tolerance=0.8,
    cell_size="0 0",
    metadata_level="Basic",
    transmission_fields="Name;MinPS;MaxPS;LowPS;HighPS;Tag;GroupName;ProductName;CenterX;CenterY;ZOrder;Shape_Length;Shape_Area;StdTime;Dimensions;Variable",
    use_time="ENABLED",
    start_time_field="StdTime",
    end_time_field="StdTime",
    time_format="YYYY/MM/DD",
    geographic_transform=None,
    max_num_of_download_items=20,
    max_num_of_records_returned=1000,
    data_source_type="GENERIC",
    minimum_pixel_contribution=1,
    processing_templates=f"None;'{variable_name}'",
    default_processing_template="None",
    time_interval=1,
    time_interval_units="Days",
    product_definition="NONE",
    product_band_definitions=None
)
# Out:
# <Result 'C:\\temp\\gfw\\gfw_sar_detection_daily_matched.gdb\\sar_detection_daily_matched'>

# %%
crf_path = os.path.join(workspace, product_name + ".crf")

with arcpy.EnvManager(parallelProcessingFactor="90%"):
    arcpy.management.CopyRaster(
        in_raster=f"{gdb_name}/{product_name}",
        out_rasterdataset=crf_path,
        config_keyword="",
        background_value=None,
        nodata_value="",
        onebit_to_eightbit="NONE",
        colormap_to_RGB="NONE",
        pixel_type="",
        scale_pixel_value="NONE",
        RGB_to_Colormap="NONE",
        format="CRF",
        transform="NONE",
        process_as_multidimensional="ALL_SLICES",
        build_multidimensional_transpose="TRANSPOSE"
    )

# %%
with arcpy.EnvManager(parallelProcessingFactor="90%"):
    out_multidimensional_raster = arcpy.ia.AggregateMultidimensionalRaster(
        in_multidimensional_raster=crf_path,
        dimension="StdTime",
        aggregation_method="SUM",
        variables=f'"{variable_name}"',
        aggregation_def="INTERVAL_KEYWORD",
        interval_keyword="MONTHLY",
        interval_value=None,
        interval_unit="",
        interval_ranges=None,
        aggregation_function="",
        ignore_nodata="DATA",
        dimensionless="DIMENSIONS",
        percentile_value=90,
        percentile_interpolation_type="NEAREST"
    )
    out_multidimensional_raster.save(crf_path.replace('daily','monthly'))

# %%
with arcpy.EnvManager(parallelProcessingFactor="90%"):
    out_multidimensional_raster = arcpy.ia.AggregateMultidimensionalRaster(
        in_multidimensional_raster=crf_path,
        dimension="StdTime",
        aggregation_method="SUM",
        variables=f'"{variable_name}"',
        aggregation_def="INTERVAL_KEYWORD",
        interval_keyword="YEARLY",
        interval_value=None,
        interval_unit="",
        interval_ranges=None,
        aggregation_function="",
        ignore_nodata="DATA",
        dimensionless="DIMENSIONS",
        percentile_value=90,
        percentile_interpolation_type="NEAREST"
    )
    out_multidimensional_raster.save(crf_path.replace('daily','annual'))

# %%
# Pause and ask the user whether to continue
while True:
    resp = input("Continue processing the notebook? [y/N]: ").strip().lower()
    if resp in ("y", "yes"):
        user_continue = True
        print("Continuing notebook execution...")
        break
    if resp in ("n", "no", ""):
        user_continue = False
        print("Notebook execution halted by user. Set 'user_continue = False'.")
        raise SystemExit("Execution stopped by user.")
    print("Please answer 'y' or 'n'.")
# Out:
# Notebook execution halted by user. Set 'user_continue = False'.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Execution stopped by user.
# c:\Users\keit8223\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone_v2\Lib\site-packages\IPython\core\interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
def overwrite_til(til_item, ras):
    copy_raster_op_til = analytics.copy_raster(
        # input_raster=os.path.join(data_dir, ras),
        input_raster=ras,
        output_name=tiled_img_item,
        tiles_only=True,
        gis=gis
    )
    return copy_raster_op_til

# %%
# search by title
items_by_title = gis.content.search(query=f'title:"{product_name}"', max_items=100)

if items_by_title:
    print("Found items by title:")
    for it in items_by_title:
        print(it.title, it.id, it.type, it.owner, it.url if hasattr(it, 'url') else "")
        tiled_img_item = gis.content.get(it.id)
        tiled_img_item
        in_ras = data_url
        result = None
        if arcpy.Exists(in_ras):
            print(f"Dataset exists: {in_ras} ...overwriting Imagery Layer")
            result = overwrite_til(tiled_img_item, in_ras)
        else:
            print(f"Dataset does not exist: {in_ras}")

if not items_by_title:
    print(f"No items found for '{product_name}' - creating Imagery Layer")
    data_url = crf_path
    print(data_url)

    ImageryLayer = copy_raster(input_raster=data_url,
                               output_name=product_name,
                               gis=gis)
    ImageryLayer
